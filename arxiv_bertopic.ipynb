# %%
from bertopic import BERTopic
import pandas as pd
import json
import numpy as np

# %%
data = "arxiv-metadata-oai-snapshot.json"

def get_metadata():
    with open(data, 'r') as f:
        for line in f:
            yield line

# %%
metadata = get_metadata()

# %%
metadata = get_metadata()
ids = []
titles = []
abstracts = []
categories = []

for paper in metadata:
    metaDict = json.loads(paper)
    try:
        try:
            year = int(metaDict['journal-ref'][-4:])    ### Example Format: "Phys.Rev.D76:013009,2007"
        except:
            year = int(metaDict['journal-ref'][-5:-1])    ### Example Format: "Phys.Rev.D76:013009,(2007)"
        if(year == 2020 or year == 2019 or year == 2018):
            ids.append(metaDict['id'])
            titles.append(metaDict['title'])
            abstracts.append(metaDict['abstract'])
            categories.append(metaDict['categories'])
    except:
        pass

# %%
df = pd.DataFrame({'id':ids,'title':titles,'abstract':abstracts,'categories':categories})

print(len(df))
# Out:
# 90989

# %%
df.head()
# Out:
#           id                                              title  \
# 0  0708.0070  Bohmian Mechanics at Space-Time Singularities....
# 1  0709.1457  What happens to geometric phase when spin-orbi...
# 2  0710.1849  Regularity of solutions of the isoperimetric p...
# 3  0712.1975         Reentrant spin glass transition in LuFe2O4
# 4  0804.3104  Teichm\"uller Structures and Dual Geometric Gi...
#
#                                             abstract  \
# 0    We develop an extension of Bohmian mechanics...
# 1    Spin-orbit interaction lifts accidental band...
# 2    In this work we consider a question in the c...
# 3    We have carried out a comprehensive investig...
# 4    The Gibbs measure theory for smooth potentia...
#
#                           categories
# 0                           quant-ph
# 1                     cond-mat.other
# 2            math.DG math.AP math.MG
# 3  cond-mat.str-el cond-mat.mtrl-sci
# 4                    math.DS math.CV

# %%
cat_list = df['categories'].unique()
print(*cat_list,sep = "\n")
# Out:
# quant-ph
# cond-mat.other
# math.DG math.AP math.MG
# cond-mat.str-el cond-mat.mtrl-sci
# math.DS math.CV
# physics.gen-ph
# math.NT
# nucl-th
# physics.atom-ph
# cond-mat.stat-mech
# gr-qc
# cs.MA cs.AI q-bio.NC
# math-ph math.MP nlin.SI quant-ph
# physics.flu-dyn math.NA physics.comp-ph
# physics.data-an physics.hist-ph physics.pop-ph
# astro-ph.CO astro-ph.HE
# q-bio.NC q-bio.QM
# math-ph math.MP
# hep-th astro-ph.CO gr-qc
# physics.comp-ph
# math.DG
# quant-ph hep-th math-ph math.MP
# astro-ph.IM astro-ph.EP
# cond-mat.str-el cond-mat.mes-hall
# cond-mat.stat-mech physics.atom-ph quant-ph
# math.NT math.AG
# math.AG math.KT
# cond-mat.dis-nn cs.DM math.CO
# math.DS
# astro-ph.IM astro-ph.CO
# astro-ph.IM astro-ph.CO cs.IT math.IT
# cond-mat.supr-con
# math.NT math.GM
# cond-mat.stat-mech cond-mat.dis-nn quant-ph
# hep-ph hep-lat hep-th
# physics.gen-ph gr-qc
# cond-mat.mes-hall
# math.PR q-bio.QM stat.AP stat.ML
# astro-ph.HE astro-ph.SR
# stat.AP math.ST stat.TH
# math.MG
# physics.plasm-ph
# math.PR
# eess.SY cs.SY
# physics.soc-ph cond-mat.dis-nn cs.SI
# math.QA
# cond-mat.soft
# hep-ph
# q-bio.PE cond-mat.stat-mech physics.bio-ph
# cond-mat.mes-hall cond-mat.mtrl-sci
# physics.ins-det hep-ex nucl-ex
# math-ph gr-qc math.AP math.MP
# cs.CG cs.DM
# nucl-ex
# math.SG
# hep-ph astro-ph.CO hep-ex
# cond-mat.quant-gas cond-mat.supr-con quant-ph
# physics.ed-ph physics.pop-ph
# math.CT
# math.GT hep-th math.RA
# math.ST stat.TH
# math.MG math.CO
# astro-ph.CO nlin.CD
# math.CO math.GT math.PR
# physics.class-ph
# math-ph math.HO math.MP
# cond-mat.mtrl-sci
# astro-ph.IM physics.ins-det
# math.FA
# physics.atom-ph physics.chem-ph physics.plasm-ph
# math.PR math.FA
# nucl-th nucl-ex
# math.CO math.GR math.RA
# math.AT
# gr-qc hep-th
# cond-mat.stat-mech cond-mat.dis-nn
# math.CO
# hep-th cond-mat.stat-mech math-ph math.MP nlin.SI
# math.AP
# math-ph cond-mat.mtrl-sci hep-th math.MP quant-ph
# math.AC
# math.AG
# quant-ph math-ph math.MP math.PR
# math.OA math.DS
# cond-mat.stat-mech cs.IT math.IT
# quant-ph math-ph math.MP math.RT
# math-ph hep-th math.MP
# math.MG math.CA math.CO
# physics.class-ph astro-ph.CO
# stat.ME econ.EM stat.AP
# math.OC math.NA
# cs.DS math.PR
# math.RA
# math.QA math.CO math.CT
# hep-ph astro-ph.SR hep-ex
# math.GR math.GT math.MG
# cond-mat.stat-mech cond-mat.soft
# hep-ph hep-ex
# cond-mat.supr-con cond-mat.str-el
# math.CA math-ph math.MP
# math.NA
# math.OC math.PR
# stat.AP
# hep-th
# nlin.CD physics.soc-ph
# cs.IT math.AG math.IT
# math.GT
# cond-mat.mtrl-sci cond-mat.stat-mech
# cond-mat.quant-gas cond-mat.str-el nucl-th physics.comp-ph
# math-ph hep-th math.MP nlin.SI
# math.RT math.QA
# gr-qc astro-ph.HE
# cs.DS
# math.GR math.AG math.GT math.MG math.RT
# math.RT
# math.RT math.CT math.KT math.RA
# gr-qc hep-th quant-ph
# cond-mat.quant-gas physics.comp-ph
# quant-ph hep-th
# math.ST math.PR stat.TH
# q-bio.MN q-bio.PE
# math.CV
# cs.PL
# math.AC math.CO
# hep-ph cond-mat.str-el hep-th
# hep-ex nucl-ex
# physics.pop-ph
# cs.IT math.IT math.PR quant-ph
# math.AP math.NA math.NT
# astro-ph.GA
# cond-mat.stat-mech hep-th math-ph math.MP nlin.CD
# math-ph math.AP math.DG math.MP
# cond-mat.str-el
# hep-th gr-qc
# stat.ME stat.ML
# cond-mat.quant-gas
# physics.soc-ph cond-mat.stat-mech cs.SI
# nucl-th math-ph math.MP quant-ph
# stat.ML
# cond-mat.stat-mech cond-mat.quant-gas hep-th math-ph math.MP
# math.RA math.AC
# math.SG math.DS
# physics.optics
# math.GR math.GT
# math-ph hep-th math.GN math.GT math.MP
# cs.CG cs.MS
# cs.IT cs.NI math.IT
# math.OC
# quant-ph cs.CC
# math.SP math.CV math.OA
# math.GT math.KT
# quant-ph physics.chem-ph
# cond-mat.stat-mech cond-mat.str-el
# math.RA cs.SC
# math.FA math.CV math.OA
# quant-ph cs.IT gr-qc hep-th math.IT
# math.LO
# math.FA math.CO
# math.OC physics.optics stat.ME
# cond-mat.supr-con cond-mat.mes-hall
# q-bio.BM cond-mat.soft physics.bio-ph
# quant-ph math-ph math.MP
# math.ST stat.ME stat.TH
# astro-ph.EP nlin.CD
# math.MG math.GT
# quant-ph physics.ed-ph
# math.CA
# math.PR cond-mat.stat-mech math.CO
# hep-ph hep-lat nucl-th
# math.KT
# cs.IT math.AG math.CO math.IT quant-ph
# physics.geo-ph cond-mat.stat-mech
# gr-qc astro-ph.CO hep-ph hep-th
# astro-ph.SR astro-ph.CO astro-ph.EP gr-qc hep-ph
# cs.MS cs.NA
# cs.NI
# q-fin.ST cs.CE
# nlin.SI math-ph math.MP
# math.RA math.DG
# math.AG math.DG math.RT
# math.AP math.PR
# math.CO cs.DS
# math.DG math-ph math.AP math.MP
# cond-mat.mes-hall quant-ph
# math.CA math.PR
# math.CO math.GR
# cs.CC cs.DS cs.LO
# math.PR cond-mat.stat-mech cs.DM math.CO
# cond-mat.mtrl-sci cond-mat.str-el
# math.CO math-ph math.MP
# astro-ph.CO
# math.GR
# cs.DS math.CO
# math-ph math.AP math.MP math.PR math.QA
# physics.soc-ph cs.CY cs.SI physics.data-an
# math.AP math.FA
# nucl-th hep-ph
# cs.DS cs.DM math.CO
# cs.CG cs.DS
# cond-mat.str-el cond-mat.mtrl-sci cond-mat.supr-con quant-ph
# hep-th cond-mat.mes-hall cond-mat.str-el
# astro-ph.CO astro-ph.GA
# nucl-ex nucl-th
# quant-ph cond-mat.str-el cs.CC
# cs.CV
# quant-ph cond-mat.other cond-mat.stat-mech
# q-bio.PE nlin.CD physics.bio-ph
# cs.DS cs.DM
# stat.ME
# cond-mat.str-el cond-mat.mes-hall hep-th math-ph math.MP quant-ph
# quant-ph cs.CR cs.IT math.AG math.IT
# cs.CR nlin.CD
# physics.gen-ph astro-ph.GA
# cond-mat.str-el cond-mat.supr-con
# math.CO cs.DS math.SP
# math.DG gr-qc
# hep-th astro-ph.CO
# cond-mat.quant-gas cond-mat.stat-mech
# physics.soc-ph cs.SI physics.data-an
# cs.CV cs.AI q-bio.NC
# nucl-ex hep-ph nucl-th
# cs.DS math.OC
# quant-ph gr-qc hep-th
# math.SP math-ph math.DG math.MP
# math.SP math-ph math.MP
# physics.flu-dyn astro-ph.EP physics.ao-ph
# cs.CL cs.LG math.OC
# physics.soc-ph cs.CL physics.data-an
# math.SG math-ph math.DG math.DS math.MP
# hep-th cond-mat.stat-mech
# math.OC math.PR q-fin.MF
# math.AG math.CV math.MG
# math-ph math.AP math.MP
# quant-ph physics.comp-ph
# hep-th math-ph math.MP
# cs.IT cs.CR math.IT
# stat.CO
# math.SG math-ph math.AG math.DG math.MP
# math-ph math.MP math.PR nlin.SI
# math.AG math.NT
# math.RA math.CO
# physics.flu-dyn physics.ao-ph physics.plasm-ph
# cond-mat.soft cond-mat.stat-mech
# gr-qc hep-th math-ph math.DG math.MP
# math.ST stat.ML stat.TH
# math.GT math.DS
# physics.comp-ph physics.data-an
# cs.GT
# quant-ph cond-mat.quant-gas
# astro-ph.HE astro-ph.IM physics.ins-det
# cs.LO
# gr-qc astro-ph.HE hep-ph hep-th physics.flu-dyn
# cs.CE math.OC
# cond-mat.mtrl-sci cond-mat.mes-hall physics.ins-det
# math.PR math-ph math.MP
# hep-ex
# physics.gen-ph physics.hist-ph
# math.CV math.DG
# math.AP gr-qc math.SP
# cond-mat.str-el math.GT math.QA quant-ph
# math-ph gr-qc hep-th math.MP quant-ph
# math.DS nlin.CD
# physics.comp-ph math.AP
# cs.SC cs.LG stat.ML
# stat.ME stat.CO
# cs.IR cs.CL cs.CV
# math.RT math.AG math.CT
# q-bio.PE nlin.CD nlin.SI physics.bio-ph
# math-ph math.CO math.MP
# cond-mat.str-el cond-mat.stat-mech hep-th quant-ph
# math.AT math.CT
# math.DG math.CO math.GT
# quant-ph cs.AI cs.DS
# math.AG cs.CG math.CO
# math.GN math.FA
# math.SG math.AG
# cond-mat.stat-mech hep-th
# math.GT cs.CC cs.DS cs.MS
# astro-ph.HE hep-ph
# q-bio.QM math.OC
# cs.CV cs.MM eess.IV math.NA
# cs.CG
# cond-mat.stat-mech cond-mat.mtrl-sci
# cond-mat.mes-hall hep-th
# math.KT math.FA math.OA
# math.DS math.GR
# math.CO math.AG
# math.GT math.AG
# math.OA math.FA
# stat.ME math.ST stat.AP stat.TH
# physics.soc-ph q-bio.PE
# math.OA cs.LO
# math.PR math.DS
# physics.optics cs.NA math.NA nlin.PS nlin.SI
# cs.IT math.IT
# gr-qc math.AP math.DG
# nlin.CD
# cs.AI cs.IT math.IT
# physics.bio-ph math-ph math.CA math.MP q-bio.PE
# q-bio.NC nlin.PS
# math.PR cs.IT math.IT
# math.CA math.MG
# cond-mat.stat-mech math.PR
# math.SP
# q-fin.MF
# quant-ph physics.atom-ph physics.optics
# cs.CE cs.ET q-bio.MN
# hep-th gr-qc math-ph math.MP
# math.RA math.NT
# math.AC math.AG
# math.GR math.AG
# cs.DC
# cond-mat.stat-mech quant-ph
# physics.soc-ph cond-mat.dis-nn q-fin.EC
# math-ph math.MP math.QA quant-ph
# math-ph math.GR math.MP
# stat.ML cs.IT math.IT
# quant-ph physics.optics
# cond-mat.mtrl-sci cond-mat.mes-hall
# math.NA math-ph math.DS math.MP
# math-ph cond-mat.dis-nn math.MP
# quant-ph cs.IT math.IT
# quant-ph cond-mat.stat-mech
# q-fin.PM math.OC math.PR q-fin.TR
# math.DS math-ph math.MP math.SP nlin.CD
# stat.ML cs.LG
# math.OC cs.SY
# math.OA
# math.DG math-ph math.AG math.MP math.SG
# cs.MS
# math.CA math.NA
# math.AG math.QA
# nlin.CG
# quant-ph cs.IT math-ph math.IT math.MP math.PR
# physics.acc-ph
# hep-th gr-qc quant-ph
# hep-ph hep-th
# physics.optics quant-ph
# gr-qc astro-ph.CO
# math.OC cs.DM cs.DS cs.RO
# physics.bio-ph physics.chem-ph
# q-bio.MN
# math.CO cs.DM
# math-ph hep-th math.AT math.DG math.MP math.QA
# math.KT math.OA
# cond-mat.mes-hall cond-mat.str-el
# hep-ph hep-ex hep-lat
# cs.IT eess.SP math.IT stat.AP
# math.CA cs.SY math.DS math.OC q-bio.CB
# cs.SY
# math-ph math.MP physics.optics
# math.CO cs.SC
# astro-ph.EP
# cs.IT cs.DM cs.DS math.IT
# cs.DS cs.DM math.OC
# q-fin.GN q-fin.EC q-fin.MF q-fin.ST
# cs.IT math.IT math.NA
# math.CO cs.CC
# cs.CG cs.GR math.DG
# q-bio.NC quant-ph
# math.AG math.CA math.NT math.SG
# cond-mat.str-el cond-mat.stat-mech physics.comp-ph
# astro-ph.IM cs.LG
# math-ph math.MP quant-ph
# math.ST econ.EM stat.TH
# physics.chem-ph cond-mat.other physics.ins-det quant-ph
# cs.IT cs.LG math.IT
# cond-mat.stat-mech cond-mat.dis-nn physics.soc-ph
# quant-ph cond-mat.stat-mech math-ph math.MP
# cs.IT math.CO math.IT math.PR
# cond-mat.str-el quant-ph
# math.NT math.CO
# math.PR math.FA math.MG
# math.AG math-ph math.MP math.QA
# cs.CY
# math.RT math.RA
# physics.ed-ph
# astro-ph.SR astro-ph.HE gr-qc
# math.CA math.CV
# math-ph hep-th math.AG math.MP math.QA
# math.MG math.DS
# cond-mat.dis-nn cond-mat.mes-hall cond-mat.soft physics.optics quant-ph
# quant-ph cond-mat.stat-mech hep-th
# nucl-th hep-ph nucl-ex
# quant-ph cond-mat.str-el
# cond-mat.stat-mech hep-ph
# math.PR math.CO math.CV
# math.GR math.DS math.GT
# q-fin.EC math.OC
# math.GT hep-th math-ph math.DG math.MP
# math.OC cs.CG
# q-bio.NC
# math.DG math-ph math.MP
# quant-ph cs.IT math-ph math.IT math.MP
# math.AG math.DS
# quant-ph math.OA
# stat.ME q-bio.MN stat.ML
# math.PR math.AP
# cs.CG cs.RO cs.SC math.AG math.RA
# cs.LG cs.CC math.NA math.OC
# cond-mat.dis-nn cond-mat.other cond-mat.str-el
# cs.RO cs.AI stat.ML
# math.AT math.QA
# gr-qc cond-mat.other hep-th
# cond-mat.mes-hall cond-mat.dis-nn
# cs.CG cs.DS math.CO
# math.CA math.GR math.PR
# math.GR math-ph math.CO math.MP math.OA
# math-ph math.MP math.PR
# math.AP math.FA math.PR
# math.PR math.CO
# math.GT math.AG math.GR
# cond-mat.str-el cond-mat.quant-gas
# math.CA math.AP
# math.GT math.CO
# hep-th astro-ph.GA quant-ph
# math.CO math.AT math.MG
# physics.bio-ph cond-mat.soft q-bio.QM q-bio.SC
# math.PR math.SP
# astro-ph.CO hep-ph hep-th
# cs.CC cs.DM math.CO
# math.SG math.GT
# math.DG hep-th math-ph math.AT math.MP
# astro-ph.IM astro-ph.GA
# cs.DM
# cs.CR
# q-bio.MN cond-mat.dis-nn cs.SI nlin.AO physics.bio-ph
# quant-ph cs.CR
# math.DS math-ph math.MP
# physics.flu-dyn
# math.AG math.DG
# math.AG math.CO
# math.CO math.CA
# stat.ME q-bio.GN q-bio.QM
# physics.ins-det cond-mat.mes-hall
# nlin.AO
# q-fin.RM math.OC
# cs.SI cs.CY cs.HC
# cs.LG
# hep-ph nucl-ex nucl-th
# math.OC cs.NA math.NA
# math.DS math.OC
# quant-ph cond-mat.mes-hall cond-mat.stat-mech
# cond-mat.stat-mech hep-th quant-ph
# astro-ph.HE astro-ph.SR gr-qc
# math.PR math.DS q-bio.PE
# nucl-th hep-ex hep-ph
# physics.comp-ph physics.plasm-ph
# physics.hist-ph
# cs.CG math.GT
# cs.CR cs.IT cs.PF math.IT
# stat.CO stat.ME
# stat.ME math.PR math.ST q-bio.PE stat.CO stat.TH
# astro-ph.HE
# quant-ph gr-qc
# cs.CY cs.HC
# physics.bio-ph cond-mat.soft cond-mat.stat-mech
# math.CT math.DS
# cs.CG math.AT
# astro-ph.CO astro-ph.GA hep-th
# eess.SY cs.SY math.OC math.PR
# quant-ph cs.LG stat.ML
# cs.DM cs.DS
# cs.SI
# quant-ph cs.CC cs.CR
# cond-mat.str-el math-ph math.MP quant-ph
# astro-ph.CO gr-qc
# hep-th hep-ph
# astro-ph.CO gr-qc hep-ph hep-th
# q-bio.CB q-bio.TO
# physics.bio-ph cond-mat.dis-nn physics.hist-ph q-bio.QM
# math.AG math.AC
# gr-qc astro-ph.CO hep-th
# astro-ph.CO gr-qc hep-th
# physics.soc-ph physics.data-an
# physics.flu-dyn astro-ph.IM astro-ph.SR
# physics.flu-dyn cond-mat.soft
# cond-mat.str-el hep-th
# cond-mat.quant-gas cond-mat.stat-mech quant-ph
# cond-mat.stat-mech physics.class-ph
# astro-ph.SR
# math.CV math-ph math.CA math.MP
# cs.GR
# math.AG math.MG
# math.CV math.PR
# gr-qc math.DG
# cs.IT cs.CC cs.FL math.IT quant-ph
# math.CA math.NT
# math.CT math.AT
# quant-ph cs.AI cs.LG
# math.DG math-ph math.MP math.SP
# math.FA math.AP math.DS
# cs.IT math.IT quant-ph
# cs.IT math.IT math.ST stat.ML stat.TH
# cs.DC cs.DS cs.SI
# math.NT math.KT
# cond-mat.dis-nn cond-mat.stat-mech cond-mat.str-el
# q-fin.ST stat.ME
# cond-mat.supr-con cond-mat.mtrl-sci
# cs.RO
# math.CO math.GT
# q-bio.PE math.PR
# cs.DC cs.IT math.IT
# stat.AP stat.CO
# cs.DC cs.DS
# math.GT math.GR
# cond-mat.str-el hep-th math-ph math.GT math.MP quant-ph
# quant-ph cond-mat.mes-hall physics.optics
# math.DS cs.CC cs.DM
# math.CA math.DS
# cs.IT math.IT math.OC stat.ML
# quant-ph cond-mat.mes-hall cond-mat.quant-gas cond-mat.stat-mech
# physics.ao-ph cond-mat.soft physics.geo-ph physics.space-ph
# cs.LG stat.ML
# physics.med-ph stat.AP
# math.CA math-ph math.MP math.SP
# math.AG math.CV
# math.AG math-ph math.MP
# cond-mat.supr-con cond-mat.stat-mech math-ph math.MP
# cs.DS cs.DC
# math.CO math.NT
# quant-ph cond-mat.mes-hall
# cs.SI cs.AI cs.MA econ.EM physics.data-an
# cs.NA cs.MS
# q-bio.NC nlin.CD
# math.DG math-ph math.MP math.OA
# math.CO cs.DM cs.DS
# math.OC cs.AI cs.LG
# stat.CO math.PR q-bio.PE stat.ME
# math.CO math-ph math.MP math.RT
# cs.CV cs.RO
# cond-mat.stat-mech physics.data-an q-fin.MF
# math.CV math.AT math.DG
# math.DG math.AP math.PR
# cs.OH
# math.CT math.QA
# math.OC cs.SY math.AG nlin.CD
# math.DG math.SP
# math.RT hep-th
# math.OC math.CO
# cond-mat.supr-con cond-mat.dis-nn
# cs.DM math.DS
# math.FA math.AG
# cond-mat.soft cond-mat.stat-mech physics.bio-ph
# math.DG math.AP math.CA
# physics.optics physics.comp-ph
# math.RT math.AC math.AG math.AT
# cs.CV cs.SD
# econ.GN q-fin.EC
# q-bio.PE q-bio.GN
# math.AC math.RT
# nlin.PS
# math.AG hep-th math.CV
# cs.IT math.IT stat.ML
# cs.CE
# cond-mat.dis-nn
# quant-ph hep-lat hep-th
# cs.ET quant-ph
# stat.ME stat.AP stat.ML
# quant-ph cs.SY math.OC
# math.DS math.PR
# physics.optics cond-mat.mes-hall quant-ph
# cs.FL
# cs.DL cs.DM cs.DS cs.SI
# stat.ML math.FA math.PR
# cs.CY cs.DC
# cs.ET cs.AR cs.DC
# math-ph gr-qc math.MP
# math.KT math.AG math.AT
# math.DG math.OC
# math.PR math.DS math.NT
# math.OC quant-ph
# cs.IT math.IT math.ST stat.TH
# quant-ph physics.data-an physics.hist-ph
# cs.CC
# nlin.CD astro-ph.GA math-ph math.DS math.MP
# physics.ins-det physics.data-an physics.optics
# astro-ph.HE astro-ph.CO gr-qc hep-ph
# hep-th gr-qc hep-ph quant-ph
# stat.ME econ.EM math.ST stat.TH
# hep-ph astro-ph.HE
# cs.SD
# cond-mat.dis-nn physics.soc-ph
# cond-mat.stat-mech cond-mat.soft physics.bio-ph physics.flu-dyn
# gr-qc astro-ph.CO hep-ph
# hep-ph hep-ex hep-lat nucl-ex nucl-th
# cs.CV cs.SY
# q-bio.PE stat.AP stat.CO
# math.LO math.CT
# stat.ML cs.IT cs.LG cs.NA math.IT math.NA math.OC
# hep-th cond-mat.stat-mech hep-ph
# cond-mat.stat-mech cond-mat.dis-nn cond-mat.str-el
# nlin.AO cond-mat.dis-nn cond-mat.mes-hall cond-mat.soft
# cs.CY cs.SE
# math.AP math.CA math.DG math.SP
# quant-ph cond-mat.mtrl-sci physics.comp-ph
# cs.DS math.OC quant-ph
# hep-th math.AG math.NT
# cond-mat.dis-nn q-bio.NC
# math.OA math-ph math.FA math.MP
# q-fin.CP q-fin.PM q-fin.TR
# math.CO cs.FL
# astro-ph.CO astro-ph.GA astro-ph.HE hep-ph
# math.RT math.PR math.RA
# cond-mat.str-el cond-mat.mtrl-sci cond-mat.supr-con
# cond-mat.str-el hep-th quant-ph
# math-ph math.AP math.CO math.MP math.QA math.RT
# cs.GR cs.CG cs.CV
# quant-ph cond-mat.mes-hall physics.atom-ph physics.optics
# math.NA cs.NA
# math.OC cs.RO cs.SY math.DS
# hep-ph nucl-th
# cs.LG math.ST stat.TH
# q-fin.MF q-fin.CP
# quant-ph math.CA
# physics.flu-dyn nlin.AO
# cs.GR cs.CG
# cs.CV cs.SY eess.SY
# physics.atom-ph cond-mat.quant-gas
# astro-ph.HE astro-ph.CO astro-ph.GA hep-ex hep-ph
# physics.bio-ph q-bio.SC
# q-bio.NC cond-mat.dis-nn physics.soc-ph
# cs.CE physics.med-ph q-bio.TO
# physics.atom-ph astro-ph.CO astro-ph.IM hep-ph physics.ins-det
# hep-ph gr-qc hep-th
# stat.ML cs.CV
# math.GN math.DS
# math.RT math.GR
# cs.NI cs.SY math.OC
# math.OC cs.LG stat.ML
# nucl-ex hep-ex
# cs.SI physics.soc-ph
# q-bio.CB
# cs.AI cs.SI
# math.NA math.AG
# math.PR cs.CG math-ph math.MP
# math.DG gr-qc math-ph math.AP math.MP
# math.CO cs.CC quant-ph
# cond-mat.quant-gas cond-mat.str-el
# stat.AP cs.IT math.IT
# physics.soc-ph math.PR
# hep-ph hep-ex physics.atom-ph
# cond-mat.mes-hall physics.optics
# quant-ph cond-mat.other physics.optics
# math.OC stat.CO
# q-fin.MF math.OC math.PR
# q-fin.RM physics.soc-ph
# cs.SY cs.CE cs.DC
# physics.plasm-ph astro-ph.SR
# physics.atom-ph nucl-th
# math.QA hep-th math.AG math.RT nlin.SI
# cs.AI
# cond-mat.dis-nn cond-mat.soft
# math-ph cond-mat.stat-mech hep-th math.MP nlin.SI
# cs.CL cs.CY cs.SI
# math.CO math.OC math.RT
# math.FA math-ph math.MP math.PR
# stat.ME cs.AI stat.ML
# gr-qc hep-th math-ph math.MP
# math.FA math-ph math.MP
# astro-ph.HE gr-qc hep-th
# cs.CL
# physics.atom-ph cond-mat.mes-hall physics.optics
# q-fin.CP cs.NA math.NA
# hep-th math-ph math.MP math.NT
# physics.atom-ph quant-ph
# cs.CC cs.DM cs.DS
# cs.IT math.IT physics.optics
# cs.LO cs.PL
# cond-mat.dis-nn cond-mat.stat-mech cond-mat.str-el physics.comp-ph
# q-bio.PE nlin.AO
# math.AP nlin.PS
# stat.ME stat.AP
# cs.GT math.OC
# hep-th math.DG
# math.GT cs.CG math.CO
# cs.FL nlin.CG
# cs.CE cs.DC physics.comp-ph
# math.DG math.AP math.SG
# stat.AP stat.CO stat.ME
# math.AG math.AT math.NT math.SG
# q-fin.RM
# math-ph math.DG math.MP
# q-fin.EC
# math.NA cs.NA math.PR stat.CO
# stat.ME econ.EM stat.AP stat.CO
# cond-mat.str-el cond-mat.stat-mech
# math.AP math-ph math.MP math.PR
# math.AP math-ph math.MP math.OC
# cs.DL cs.SI physics.soc-ph
# cond-mat.mtrl-sci physics.chem-ph
# physics.flu-dyn physics.geo-ph
# cs.DM cs.GR
# math.CA math-ph math.FA math.MP
# math.AP gr-qc math.DG
# nlin.PS math-ph math.DS math.MP nlin.SI
# nlin.AO physics.soc-ph
# math.DS math.AG math.GN
# cs.LG cs.NA math.NA stat.ML
# cond-mat.str-el cond-mat.dis-nn cond-mat.quant-gas
# math.AP math-ph math.MP
# hep-th math.AG math.QA math.RT nlin.SI
# math.HO math.DS math.GT nlin.CD
# math.SP math-ph math.FA math.MP
# math.GR math.RT
# math.GN
# math.AG math-ph math.DG math.MP
# physics.bio-ph cond-mat.soft
# math.FA math.CA
# math.RA math.FA math.NA
# physics.soc-ph
# physics.med-ph cs.CV math.NA
# quant-ph physics.data-an
# math.RT math.NT
# cs.SI math.MG physics.soc-ph
# physics.class-ph physics.optics
# stat.CO stat.ML
# stat.CO cs.DC
# cs.LG cs.CV cs.DB
# physics.optics cond-mat.mes-hall cond-mat.mtrl-sci quant-ph
# astro-ph.CO hep-ph
# cond-mat.quant-gas physics.atom-ph quant-ph
# math-ph cs.IT math.IT math.MP math.OA quant-ph
# cond-mat.quant-gas cond-mat.mes-hall quant-ph
# gr-qc math-ph math.AP math.MP
# cs.SI cond-mat.stat-mech nlin.AO physics.soc-ph stat.ME
# q-fin.MF math.PR
# math-ph math.AG math.MP math.NT
# math.DG math.AP
# physics.data-an q-bio.NC
# cond-mat.str-el cond-mat.dis-nn cond-mat.mes-hall
# astro-ph.EP nlin.CD physics.data-an physics.geo-ph
# cs.DM cs.DS math.CO
# cs.SY stat.CO
# math-ph hep-th math.AG math.MP
# cs.SE cs.AI cs.CL cs.IR
# stat.ME econ.EM q-fin.PM stat.AP stat.CO
# math.DS nlin.PS physics.flu-dyn
# q-bio.NC math.DS
# math.AG math.CV math.GT
# physics.soc-ph cond-mat.stat-mech
# math.SP math.AP
# quant-ph math.ST stat.ME stat.ML stat.TH
# math.QA math-ph math.DG math.MP
# math.DS cs.SY
# cond-mat.mes-hall physics.optics quant-ph
# math.KT math.DG math.OA
# physics.flu-dyn cond-mat.stat-mech
# physics.plasm-ph cond-mat.soft
# cs.IT cs.DC math.IT
# cs.NA cs.CE physics.comp-ph
# physics.bio-ph q-bio.CB
# cs.NI cs.DC cs.DS
# cond-mat.str-el cond-mat.mes-hall quant-ph
# cond-mat.str-el cond-mat.dis-nn cond-mat.supr-con
# physics.comp-ph cond-mat.mtrl-sci physics.atm-clus physics.chem-ph
# math.PR math.CA
# quant-ph physics.bio-ph physics.data-an physics.soc-ph
# math.QA math.RT
# cs.SE cs.DC
# math.CO math.PR
# cs.MA cs.CE cs.LG math.ST stat.TH
# math.AG math.AT
# quant-ph astro-ph.CO hep-th
# astro-ph.CO astro-ph.EP
# quant-ph astro-ph.CO hep-ph
# cs.DS math.OC physics.comp-ph physics.med-ph
# math.PR math-ph math.CV math.MP
# nucl-th hep-ph hep-th physics.flu-dyn
# hep-lat hep-ph
# math.DS math.CA
# cond-mat.quant-gas quant-ph
# cond-mat.mes-hall cond-mat.dis-nn cond-mat.str-el hep-th
# hep-th math.DG math.SG
# quant-ph cs.LG cs.NE
# cond-mat.soft physics.ao-ph physics.geo-ph
# math.QA math-ph math.MP
# nlin.CD math.DS math.ST stat.TH
# stat.ML stat.AP
# cs.IT math.IT math.PR math.ST stat.TH
# math.KT math.AT math.GT
# astro-ph.GA astro-ph.HE
# nlin.AO math.DS
# quant-ph math.CT math.QA
# cs.DB
# math.CO math.HO
# cond-mat.mes-hall cond-mat.dis-nn quant-ph
# cond-mat.quant-gas cond-mat.str-el quant-ph
# math.AP math.CA
# physics.soc-ph cs.MA q-fin.TR
# cs.GT cs.SI
# astro-ph.IM
# math.PR math-ph math.CO math.MP
# physics.bio-ph physics.med-ph q-bio.NC
# quant-ph cond-mat.stat-mech cond-mat.str-el math-ph math.CO math.MP
# physics.chem-ph
# math.OC cs.IT cs.SY math.IT
# math.GN math.LO
# math.OC math.AP math.FA
# math.MG math.CO math.OC
# math.GR cs.DM cs.FL
# math.CO cs.DM math.PR
# q-fin.PM
# q-fin.PM math.OC
# math.AP math-ph math.MP math.PR math.SP
# math.OA math.DS math.FA math.KT
# cs.DM cs.DC math.CO
# math.DG math.AP math.FA
# cond-mat.mes-hall cond-mat.quant-gas quant-ph
# physics.med-ph physics.bio-ph quant-ph
# math.CT math.AC math.RT
# math.OC math.DS
# math.RA math.SP
# math.RA math.OA
# math.HO math.FA
# math.RT math-ph math.AG math.MP math.QA
# math.DS math-ph math.CO math.MP
# physics.geo-ph cond-mat.soft physics.flu-dyn
# cs.CE math.NA
# math.ST cs.SI physics.soc-ph stat.TH
# cs.IR cs.LG
# cs.SY cs.DC cs.RO math.OC
# hep-ex physics.ins-det
# math.OC cs.SY math.DS
# math.PR math.GR
# q-bio.SC physics.bio-ph physics.chem-ph
# math.OC math.MG
# physics.soc-ph nlin.AO
# stat.ML stat.CO
# math-ph math.MP nlin.CD physics.class-ph
# math.DS math.OC nlin.CD
# q-fin.TR q-fin.CP q-fin.ST
# math.AP math.DS
# math.AP math.OC
# cond-mat.quant-gas cond-mat.mes-hall cond-mat.stat-mech
# cs.IT math.FA math.IT
# math.DG math.CT
# cond-mat.supr-con hep-th
# cs.IT math.AC math.IT
# math.AG math.CO math.OC
# astro-ph.HE astro-ph.GA
# hep-ph hep-ex nucl-ex nucl-th
# math.NA math.PR
# gr-qc physics.optics
# math.AP math.NA
# math.QA math-ph math.CT math.GT math.MP quant-ph
# physics.soc-ph cond-mat.stat-mech nlin.PS
# q-fin.PM q-fin.CP q-fin.TR
# quant-ph cond-mat.mes-hall cond-mat.supr-con
# gr-qc quant-ph
# cond-mat.stat-mech nlin.CD
# q-fin.ST q-fin.RM
# astro-ph.CO astro-ph.GA hep-ex hep-ph nucl-ex
# cond-mat.str-el hep-th math-ph math.MP
# math.DG hep-th
# math.CA math.DS math.PR
# physics.flu-dyn cond-mat.mes-hall cond-mat.soft
# math-ph hep-th math.AG math.CO math.MP nlin.SI
# math.OC cs.NA math.PR
# physics.flu-dyn math.AP math.OC
# hep-ph hep-ex nucl-th
# math.CT math.AG math.KT
# math.QA math.CT math.RT
# math.AP math.SP
# hep-th gr-qc hep-ph nucl-th
# hep-th hep-ph nucl-th
# math.DG hep-th math.CV
# math.CO cs.FL cs.LO math.RT
# math.NA math.AP math.DG
# math.CV math-ph math.MP
# math.AT cs.CG math.CT
# cond-mat.str-el cond-mat.dis-nn
# math.CO math.MG
# physics.bio-ph
# cond-mat.mes-hall cond-mat.stat-mech quant-ph
# cs.MS cs.SY math.OC
# nlin.SI
# physics.soc-ph cs.CY cs.HC cs.SI
# stat.ML cs.CV physics.data-an
# math.PR math.AG math.NA
# math.GR cs.CR cs.IT math.IT
# cs.GT cs.DS
# quant-ph hep-th math-ph math.MP math.SP
# astro-ph.IM astro-ph.HE physics.comp-ph physics.plasm-ph physics.space-ph
# stat.ML cs.SY math.OC
# math-ph cond-mat.dis-nn cond-mat.supr-con hep-lat hep-th math.MP
# math.NA physics.comp-ph
# hep-th math-ph math.DG math.MP
# physics.flu-dyn math-ph math.MP
# hep-th math-ph math.CO math.MP
# cs.CG cs.RO math.MG
# quant-ph cond-mat.stat-mech gr-qc hep-th
# q-bio.NC q-bio.PE
# physics.soc-ph cs.SI
# physics.comp-ph physics.geo-ph
# math.AG math.RT
# math.CO cs.IT math.IT
# nucl-th astro-ph.CO hep-ph
# cs.SY math.DS
# quant-ph cond-mat.mes-hall physics.atom-ph
# math.CA cs.IT math.IT
# q-bio.NC cs.IT math.IT
# hep-th gr-qc hep-ph
# q-bio.QM cond-mat.soft q-bio.CB
# math.SP math-ph math.AP math.MP
# q-fin.GN
# math.OA math.QA
# astro-ph.SR astro-ph.HE
# hep-ex hep-ph physics.ins-det
# cond-mat.quant-gas cond-mat.stat-mech cond-mat.str-el
# astro-ph.HE astro-ph.CO astro-ph.GA hep-ph
# math.OC cs.DS
# stat.CO cs.LG stat.ML
# math.GT math.QA math.RT
# math.AC math.CO math.RA
# quant-ph cond-mat.quant-gas physics.atom-ph
# quant-ph cond-mat.other
# astro-ph.HE astro-ph.GA hep-ph
# math.LO cs.CC
# cs.CL physics.soc-ph
# gr-qc hep-ph hep-th
# cond-mat.str-el physics.comp-ph quant-ph
# math-ph math.KT math.MP
# astro-ph.CO astro-ph.GA gr-qc hep-ph
# hep-th cond-mat.stat-mech gr-qc
# math.PR math.ST stat.TH
# math.MG cond-mat.mtrl-sci math.CO
# cs.LG cs.AI stat.ML
# math.QA hep-th math.RA
# nlin.SI cond-mat.supr-con math-ph math.MP
# nucl-ex nucl-th physics.ins-det
# math-ph cond-mat.str-el cond-mat.supr-con hep-lat math.MP
# math.FA cs.IT math.IT
# cond-mat.str-el cond-mat.mtrl-sci math-ph math.MP
# cond-mat.str-el cond-mat.mes-hall cond-mat.mtrl-sci
# cs.CV cs.IR
# cs.CC cs.LO
# math.GM
# q-bio.PE
# cs.IR cs.LG cs.SD
# math.OC cs.AI cs.SY eess.SY
# cs.SY cs.SI math.OC physics.soc-ph
# cs.LG cs.IT math.IT stat.ML
# cs.CV q-bio.NC
# physics.plasm-ph physics.comp-ph
# nucl-th astro-ph.HE astro-ph.SR
# math.GR math.NT
# math.AP gr-qc math-ph math.DG math.MP
# math.GT math.AT math.DG
# cs.SD cs.AI cs.NE
# physics.ins-det physics.optics
# math.AP cond-mat.mtrl-sci physics.comp-ph
# cond-mat.dis-nn quant-ph
# nlin.AO cs.SY stat.ML
# math.NT math.GR
# physics.comp-ph physics.flu-dyn
# cs.SI cs.DS physics.soc-ph
# math.ST math.OC stat.ML stat.TH
# hep-th math.AG math.AT
# quant-ph cs.AI cs.LG cs.NE math.OC
# math.AG math.AT math.CV math.DG math.DS
# math.OC math.AG math.MG
# math.CO math.OC
# stat.CO stat.AP stat.ME
# cond-mat.stat-mech physics.comp-ph
# cond-mat.soft physics.bio-ph q-bio.SC
# physics.med-ph
# stat.AP cs.CR
# hep-th cond-mat.str-el gr-qc quant-ph
# cs.CV eess.IV
# cond-mat.mes-hall cond-mat.supr-con quant-ph
# cs.IT math.IT math.PR
# cs.SY cs.GT
# q-bio.QM cond-mat.stat-mech hep-th q-bio.BM
# q-bio.MN physics.bio-ph
# quant-ph cs.ET cs.PL
# q-fin.EC cond-mat.dis-nn nlin.CD physics.soc-ph
# cond-mat.soft physics.ins-det
# math.DG math.AG math.CV math.RT
# cs.DC cs.NA math.NA stat.CO
# cs.IT cs.DM math.IT
# math.PR q-fin.RM
# stat.AP cs.LG
# nucl-th cond-mat.quant-gas cond-mat.stat-mech hep-ph nucl-ex
# hep-th math.AG math.SG
# cond-mat.mes-hall cond-mat.soft physics.class-ph
# nlin.PS physics.soc-ph
# math-ph cond-mat.mes-hall math.MP
# cond-mat.str-el cond-mat.supr-con quant-ph
# astro-ph.IM astro-ph.GA astro-ph.HE cs.LG gr-qc
# hep-ph astro-ph.CO astro-ph.HE
# math.DS math-ph math.MP math.NT
# math.NT math.FA
# stat.ME cs.CV physics.data-an
# math.GT math.GN math.GR
# nucl-ex hep-ex nucl-th
# stat.ML math.ST quant-ph stat.TH
# math.CO math.DS math.PR
# nucl-th hep-lat hep-ph
# math.NA math.AP
# math.PR math.RA
# nlin.CG math-ph math.MP nlin.PS
# math.NA cs.CE cs.NA
# cond-mat.quant-gas cond-mat.mes-hall cond-mat.str-el quant-ph
# cond-mat.str-el cond-mat.quant-gas cond-mat.supr-con
# math.RT math.AG
# math-ph math.MP nlin.SI
# math.QA math-ph math.CT math.MP math.RA math.RT
# cond-mat.supr-con cond-mat.mes-hall quant-ph
# physics.soc-ph cond-mat.dis-nn cs.SI math.DS nlin.AO
# cs.CL cs.HC
# cs.DM cs.GT quant-ph
# stat.CO cs.DS
# math.NT math.NA
# math-ph math.FA math.MP
# hep-th cond-mat.stat-mech quant-ph
# math-ph math.MP math.SP
# cond-mat.mes-hall cond-mat.supr-con
# hep-ph hep-th nucl-th
# cond-mat.mes-hall cond-mat.other math.DS
# math.NA physics.flu-dyn
# quant-ph astro-ph.CO hep-ph hep-th
# math.CO math.RT
# math.RT math.GR math.RA
# cs.SE
# cs.ET
# q-bio.QM cond-mat.stat-mech
# math.PR math.NA
# cond-mat.str-el quant-ph stat.ML
# nlin.SI cond-mat.mtrl-sci
# math.CO math.DS
# quant-ph cond-mat.mes-hall cond-mat.quant-gas physics.optics
# cs.DS cs.SI physics.soc-ph
# cs.NA cs.DS
# math.AG cs.CG cs.SC math.CO
# cs.MM
# math.DS nlin.CD q-bio.NC
# cs.IT cond-mat.dis-nn math-ph math.IT math.MP
# math.AT hep-th math-ph math.GT math.MP math.QA
# math.OC q-fin.MF
# cs.NA
# cs.HC
# math.CA math.DG
# physics.soc-ph cond-mat.stat-mech physics.data-an
# cond-mat.mes-hall cond-mat.dis-nn physics.comp-ph
# math.PR math.LO
# q-bio.PE q-bio.QM stat.CO stat.ME
# physics.atom-ph physics.optics
# math.OC cs.SY physics.ins-det
# cond-mat.dis-nn cond-mat.stat-mech
# cs.SY math.OC
# physics.data-an cond-mat.stat-mech
# cs.AI cs.CY
# cs.CV cs.LG stat.ML
# physics.ins-det
# math.CT math.RT
# math.AP math.DS math.OC
# cs.LO math.CT
# math.DS q-bio.MN
# math.FA math.AP math.MG
# math-ph cond-mat.str-el hep-th math.MP
# math.DS math.GT
# hep-ph astro-ph.HE hep-th
# math.AP cond-mat.mtrl-sci math-ph math.MP
# math.QA math.AT math.CT
# cs.IT cs.DS math.IT
# stat.OT
# nlin.PS physics.flu-dyn
# math-ph gr-qc hep-th math.DG math.MP
# math.PR cond-mat.stat-mech
# cond-mat.dis-nn cond-mat.stat-mech cs.AI cs.CC
# astro-ph.SR astro-ph.EP
# cs.CR math.PR
# cs.LG cs.HC
# cond-mat.mtrl-sci cond-mat.other physics.chem-ph physics.comp-ph
# cs.LG cond-mat.dis-nn cs.NE stat.ML
# math-ph math.CO math.MP math.PR
# stat.ML cs.IT cs.LG math.IT
# nlin.SI math-ph math.DS math.MP
# stat.ME cs.NA math.NA math.ST stat.CO stat.TH
# math.GT math.GN math.RA
# math.DS math.FA math.SP
# cond-mat.stat-mech physics.bio-ph
# physics.bio-ph cond-mat.soft q-bio.CB
# astro-ph.GA astro-ph.CO
# quant-ph cs.NE cs.SY
# cond-mat.mes-hall cond-mat.other
# q-fin.RM math.PR
# cond-mat.other physics.class-ph
# hep-ph astro-ph.CO
# cs.CC cs.DM
# stat.ML cs.LG cs.NA
# cond-mat.quant-gas hep-th
# math-ph math.AP math.MP math.SP physics.plasm-ph
# math.FA math.DS
# cond-mat.mes-hall cond-mat.dis-nn cond-mat.stat-mech quant-ph
# physics.data-an stat.ML
# cond-mat.other physics.chem-ph
# quant-ph physics.atom-ph
# math.CO math.PR math.RT
# math.PR math.OC q-bio.MN q-bio.PE q-bio.QM
# astro-ph.HE astro-ph.SR cond-mat.stat-mech physics.plasm-ph physics.space-ph
# cond-mat.dis-nn cs.LG physics.data-an stat.ML
# math.OC math-ph math.MP
# quant-ph cond-mat.mes-hall cs.CC
# physics.ed-ph physics.ins-det
# nucl-th hep-lat hep-ph nucl-ex
# cond-mat.stat-mech cond-mat.str-el math-ph math.MP quant-ph
# cs.CG math.CO
# quant-ph physics.acc-ph physics.optics
# astro-ph.IM astro-ph.EP astro-ph.SR
# nlin.CD math-ph math.AP math.DS math.MP
# physics.comp-ph cond-mat.mes-hall
# physics.bio-ph cond-mat.mes-hall q-bio.BM quant-ph
# hep-th math-ph math.MP nlin.CD
# stat.ME physics.ao-ph stat.AP
# math.PR cond-mat.stat-mech math-ph math.AP math.MP
# math.AC cs.SC
# cs.RO cs.CV
# stat.ME cs.CV physics.data-an stat.ML
# cs.DS cs.CC
# math.MG math.AC math.AG
# cond-mat.stat-mech cond-mat.str-el hep-th quant-ph
# quant-ph cs.CR cs.IT math.IT
# gr-qc hep-th math-ph math.MP quant-ph
# physics.flu-dyn nlin.PS
# quant-ph cond-mat.supr-con
# cond-mat.mtrl-sci cond-mat.mes-hall physics.optics
# quant-ph cond-mat.str-el hep-th
# quant-ph cond-mat.dis-nn cs.CY cs.SI physics.soc-ph
# math-ph cond-mat.quant-gas math.MP
# cs.NE
# q-fin.GN econ.GN physics.soc-ph q-fin.EC q-fin.RM
# hep-th cond-mat.str-el
# math.CT math.RA
# math.HO math.PR
# math.QA hep-th math.AT
# cond-mat.supr-con cond-mat.quant-gas cond-mat.str-el
# stat.ML cs.CR cs.DC cs.LG
# physics.soc-ph cs.IT cs.SI math.IT stat.AP
# cs.OH quant-ph
# math.HO math.CV
# math.QA math.KT math.RA
# stat.ML cs.DC cs.LG cs.NA stat.ME
# physics.chem-ph q-bio.BM quant-ph
# physics.data-an
# physics.chem-ph cond-mat.other cond-mat.str-el physics.comp-ph
# q-bio.BM cond-mat.stat-mech q-bio.QM
# quant-ph math.PR
# q-fin.EC cs.SI econ.TH
# cond-mat.other cond-mat.quant-gas nlin.PS physics.flu-dyn
# astro-ph.HE cond-mat.stat-mech physics.space-ph
# cond-mat.dis-nn nlin.CD
# nlin.PS math.DS physics.bio-ph
# cs.LG cs.CV
# cond-mat.stat-mech cond-mat.quant-gas hep-th quant-ph
# math.GR math.AG math.AT
# math.ST cond-mat.stat-mech stat.TH
# math.AT math-ph math.MP
# nlin.AO cond-mat.dis-nn math.DS nlin.PS
# quant-ph math-ph math.FA math.MP
# math.AT math.GT math.KT math.RT
# quant-ph cs.CE
# cs.DS cs.DM cs.SI
# math.NA cs.NA math.PR math.ST stat.CO stat.TH
# physics.bio-ph cond-mat.stat-mech
# cond-mat.dis-nn cond-mat.quant-gas cond-mat.str-el quant-ph
# physics.soc-ph cs.IT math.IT
# stat.ML cs.LG stat.CO stat.ME
# physics.bio-ph q-bio.MN
# math.NA math.CA
# cs.CV stat.ME
# cond-mat.dis-nn cond-mat.str-el
# quant-ph cs.CR cs.CY
# math-ph math.AP math.MP quant-ph
# cs.SI cs.CR cs.LG
# math.OA math.CO math.GR math.RT
# cond-mat.soft physics.bio-ph
# physics.optics nlin.PS
# math.OC stat.ML
# math.OC math.DS math.SP
# astro-ph.HE physics.plasm-ph
# cond-mat.supr-con physics.class-ph
# math.PR q-bio.PE
# quant-ph cond-mat.mes-hall nlin.CD
# math.QA hep-th math-ph math.MP
# quant-ph cond-mat.mes-hall cond-mat.stat-mech physics.atom-ph
# cond-mat.str-el cond-mat.other physics.chem-ph physics.comp-ph quant-ph
# cond-mat.dis-nn nlin.CD q-bio.NC
# math.OC cs.MA
# physics.atom-ph physics.atm-clus
# physics.atom-ph physics.optics quant-ph
# quant-ph cond-mat.quant-gas cs.CC
# cond-mat.dis-nn cond-mat.quant-gas physics.comp-ph quant-ph
# physics.ins-det astro-ph.CO cond-mat.mtrl-sci hep-ex physics.comp-ph
# math.OC cs.GT cs.SY
# cond-mat.mes-hall cond-mat.mtrl-sci physics.optics
# math-ph cond-mat.stat-mech math.MP math.OC math.PR quant-ph
# math.GT math.QA
# q-bio.BM
# physics.atom-ph cond-mat.quant-gas quant-ph
# quant-ph math.FA
# stat.ME stat.CO stat.ML
# math.DG math.AG math.CV
# math.CO math.AG math.AT math.RT
# q-fin.PR physics.soc-ph
# cs.CV cs.AI
# physics.ao-ph
# cond-mat.dis-nn cond-mat.stat-mech cond-mat.str-el quant-ph
# cs.AI cs.CL quant-ph
# cs.DL cond-mat.stat-mech physics.data-an stat.AP
# q-fin.TR cond-mat.stat-mech
# physics.atom-ph cond-mat.stat-mech
# cs.CG cs.CC math.GT
# physics.flu-dyn physics.comp-ph
# physics.gen-ph physics.flu-dyn
# math.PR math.CO math.RT
# physics.comp-ph physics.med-ph
# math.AP math-ph math.FA math.MP math.PR
# cs.NE cs.CV
# physics.soc-ph cs.DL cs.SI physics.data-an
# math.NA math.FA math.OC
# math-ph math.CV math.MP
# physics.optics cond-mat.dis-nn cond-mat.mes-hall physics.bio-ph
# physics.soc-ph cond-mat.stat-mech cs.CL physics.data-an
# cond-mat.soft cond-mat.other physics.comp-ph
# quant-ph physics.hist-ph
# physics.data-an cond-mat.mtrl-sci
# nucl-th astro-ph.HE nucl-ex
# cs.CE q-bio.PE q-bio.QM
# math.AC math.AG math.NT
# q-bio.PE math.PR stat.AP
# nlin.CG nlin.AO
# cond-mat.stat-mech nlin.CG
# cond-mat.mes-hall cond-mat.mtrl-sci quant-ph
# stat.AP cs.SI physics.soc-ph
# math.NA math.DG
# gr-qc astro-ph.CO nlin.AO physics.class-ph
# stat.ME astro-ph.IM stat.AP
# cs.GT cs.SY math.OC
# cond-mat.stat-mech cond-mat.dis-nn cond-mat.soft
# cond-mat.dis-nn cond-mat.stat-mech math-ph math.MP math.PR
# cs.RO cs.AI
# cs.NE cs.AI
# cond-mat.mes-hall physics.ins-det quant-ph
# quant-ph cond-mat.dis-nn cond-mat.stat-mech cond-mat.str-el
# cond-mat.quant-gas cond-mat.other cond-mat.stat-mech nlin.PS
# physics.space-ph
# gr-qc astro-ph.HE hep-ph hep-th
# cs.SE cs.HC
# nlin.CD physics.bio-ph
# physics.bio-ph cond-mat.soft cond-mat.stat-mech q-bio.SC
# physics.comp-ph cond-mat.soft
# math.OC cs.LG cs.NA math.NA
# math.CT math.OC
# math.LO math.CO
# stat.AP cs.CE physics.soc-ph
# physics.soc-ph cond-mat.dis-nn cond-mat.stat-mech
# cond-mat.mtrl-sci cond-mat.mes-hall cond-mat.str-el
# cs.GT cs.NI
# cond-mat.soft cond-mat.dis-nn cond-mat.stat-mech
# q-fin.PM q-fin.CP q-fin.GN q-fin.RM
# math.HO math.LO
# stat.CO stat.AP
# quant-ph cond-mat.stat-mech cond-mat.supr-con
# cs.MS cs.PF
# physics.comp-ph astro-ph.HE gr-qc physics.flu-dyn
# hep-th math-ph math.GT math.MP math.QA
# quant-ph math.OC
# physics.flu-dyn hep-th nlin.CD
# quant-ph physics.atom-ph physics.ins-det
# hep-ex hep-ph physics.plasm-ph
# math.FA math.OC
# math-ph hep-th math.AT math.MP
# math.SG math.AG math.DG
# physics.gen-ph math-ph math.MP
# quant-ph cond-mat.dis-nn hep-th
# math.NT math.GR math.SP
# cond-mat.soft physics.flu-dyn q-bio.CB
# astro-ph.EP astro-ph.IM
# math-ph cond-mat.stat-mech math.CA math.MP math.PR nlin.SI
# cs.CG cs.GR math.DG math.NA
# gr-qc physics.hist-ph
# math.PR cs.IT math.FA math.IT
# physics.comp-ph cond-mat.dis-nn cond-mat.str-el cs.DC
# stat.CO cs.CE cs.LG stat.ME stat.ML
# math.HO math.NT
# physics.soc-ph cs.LG cs.SI nlin.AO
# math-ph cs.CC math.MP
# math.NA math.OC
# stat.CO econ.EM stat.AP stat.ME
# hep-th math.AG
# physics.flu-dyn astro-ph.GA math-ph math.MP physics.plasm-ph
# physics.flu-dyn astro-ph.HE gr-qc math-ph math.MP
# cs.SI cs.MA
# quant-ph cond-mat.dis-nn cond-mat.mes-hall cond-mat.quant-gas
# cs.SI cond-mat.stat-mech physics.soc-ph stat.ML
# math.NT math.CA math.CO
# quant-ph cond-mat.dis-nn
# cond-mat.quant-gas cond-mat.stat-mech cond-mat.str-el quant-ph
# cs.LG math.OC
# physics.comp-ph math.NA
# astro-ph.GA astro-ph.CO hep-ph
# cs.IR cs.AI
# astro-ph.IM astro-ph.HE
# physics.optics cond-mat.mtrl-sci
# cond-mat.quant-gas physics.flu-dyn quant-ph
# hep-ph hep-lat hep-th nucl-th
# q-bio.PE q-bio.NC
# astro-ph.CO hep-th
# hep-ph physics.atm-clus quant-ph
# physics.bio-ph physics.flu-dyn q-bio.CB
# physics.bio-ph q-bio.BM
# math.FA math.MG
# gr-qc math-ph math.DG math.MP
# math.OA math.CT
# math.PR math.AP math.CA
# hep-th math-ph math.MP quant-ph
# physics.hist-ph gr-qc hep-th
# cond-mat.stat-mech nlin.PS physics.flu-dyn
# math-ph hep-th math.MP math.QA
# cs.CC cs.AI cs.DM
# cs.CL cs.AI
# cond-mat.dis-nn cond-mat.stat-mech cs.IT cs.LG math.IT stat.ML
# cond-mat.quant-gas cond-mat.other
# physics.comp-ph math.DS physics.data-an physics.flu-dyn
# cond-mat.stat-mech hep-lat hep-ph hep-th
# math.AP gr-qc math-ph math.MP
# physics.app-ph cond-mat.mtrl-sci
# math.AP physics.flu-dyn
# math-ph math.MP physics.class-ph
# cond-mat.other cond-mat.mtrl-sci
# hep-ph astro-ph.CO gr-qc hep-th
# physics.med-ph physics.bio-ph
# math.OC cs.CC
# astro-ph.HE astro-ph.IM
# cond-mat.other cond-mat.mes-hall cond-mat.str-el physics.flu-dyn physics.plasm-ph
# physics.soc-ph cs.MA nlin.CG
# physics.data-an physics.med-ph
# physics.optics gr-qc
# physics.soc-ph cond-mat.stat-mech cs.MA cs.SI q-bio.PE
# nucl-th hep-ex hep-ph nucl-ex
# physics.app-ph cond-mat.mtrl-sci physics.optics
# math.OC math.FA
# cond-mat.dis-nn cond-mat.mtrl-sci
# math.CA math-ph math.CO math.MP
# cond-mat.mes-hall cond-mat.mtrl-sci cond-mat.quant-gas cond-mat.str-el quant-ph
# astro-ph.SR astro-ph.CO astro-ph.IM physics.data-an
# math.OC math.AP math.DS
# math.DS math.AG
# quant-ph cs.LO
# hep-th nucl-th physics.flu-dyn
# cond-mat.mes-hall cond-mat.mtrl-sci cond-mat.str-el
# hep-ph math-ph math.MP
# cond-mat.stat-mech physics.chem-ph q-bio.QM
# cond-mat.str-el cond-mat.mtrl-sci cond-mat.other cond-mat.soft
# math.AG math.AT math.CV
# hep-ph hep-ex hep-lat nucl-th
# quant-ph cond-mat.str-el gr-qc hep-th
# cond-mat.mes-hall physics.app-ph quant-ph
# physics.data-an physics.ao-ph
# quant-ph cond-mat.other cond-mat.quant-gas cond-mat.stat-mech
# physics.bio-ph cond-mat.soft cond-mat.stat-mech cs.ET
# math.AP cond-mat.mes-hall nlin.PS
# quant-ph cs.DM math-ph math.CO math.MP
# cs.CR cs.CY cs.IR cs.LG
# cs.LG cond-mat.stat-mech stat.ML
# hep-ph quant-ph
# math.PR cond-mat.dis-nn math-ph math.MP
# cond-mat.quant-gas cond-mat.str-el physics.atom-ph
# physics.plasm-ph astro-ph.SR physics.space-ph
# astro-ph.GA gr-qc
# physics.data-an cond-mat.stat-mech cs.IT math.IT math.ST stat.ML stat.TH
# physics.acc-ph astro-ph.HE physics.optics physics.plasm-ph
# cond-mat.mes-hall physics.app-ph
# astro-ph.HE astro-ph.GA gr-qc
# astro-ph.HE cond-mat.stat-mech hep-ph
# cond-mat.stat-mech math.PR math.ST stat.TH
# cond-mat.str-el physics.chem-ph physics.comp-ph
# math-ph math.CA math.MP math.SP
# quant-ph cs.CC cs.DS
# physics.app-ph cond-mat.mtrl-sci physics.ins-det physics.med-ph quant-ph
# hep-ex hep-ph
# hep-ex hep-ph stat.ML
# cs.IT cs.LG math.IT stat.ML
# gr-qc math-ph math.MP
# nucl-th hep-ph physics.atom-ph
# cs.SI cs.LG physics.data-an
# cond-mat.soft cond-mat.mtrl-sci
# hep-th astro-ph.CO gr-qc hep-ph
# math-ph cond-mat.mes-hall cond-mat.quant-gas math.AP math.MP
# math.RT math.QA math.RA
# math.ST math-ph math.MP quant-ph stat.TH
# cond-mat.stat-mech cond-mat.mes-hall
# physics.class-ph physics.comp-ph
# math.CA astro-ph.SR
# cs.LG cs.HC cs.SI
# quant-ph stat.AP
# cs.CC math.AG
# math.AP math.CA math.SP
# physics.optics cond-mat.other quant-ph
# cs.CL cs.SI
# physics.optics physics.ins-det
# hep-th cond-mat.stat-mech cond-mat.str-el
# cs.CV cs.IR cs.LG physics.app-ph physics.optics
# math.DS cs.NA math.NA nlin.CD
# quant-ph nlin.AO
# physics.soc-ph physics.data-an stat.CO
# math-ph cond-mat.mtrl-sci cond-mat.stat-mech math.MP
# cond-mat.quant-gas cond-mat.supr-con nucl-th
# math-ph cond-mat.dis-nn math.MP math.PR math.SP
# astro-ph.HE astro-ph.CO hep-ph nucl-th
# nlin.PS q-bio.PE
# astro-ph.EP astro-ph.SR physics.space-ph
# physics.comp-ph astro-ph.IM hep-ex
# astro-ph.IM physics.ao-ph
# math-ph gr-qc math.CA math.MP
# cond-mat.str-el cond-mat.stat-mech hep-th
# physics.comp-ph cond-mat.mtrl-sci
# physics.ins-det hep-ex
# math.SP math.CA math.FA
# cond-mat.quant-gas cond-mat.dis-nn
# nucl-th hep-lat nucl-ex physics.atm-clus
# physics.bio-ph cond-mat.soft q-bio.TO
# physics.ao-ph astro-ph.HE hep-ex
# hep-lat cond-mat.stat-mech hep-ph nucl-th physics.comp-ph
# physics.data-an q-bio.QM
# math.OC cs.DC cs.NA math.NA stat.ML
# cs.LG cs.AI
# cond-mat.quant-gas physics.atom-ph
# stat.AP q-bio.NC
# math.NA stat.CO
# math.PR stat.CO
# gr-qc math.AP
# cond-mat.quant-gas nlin.CD quant-ph
# cond-mat.str-el hep-lat hep-th math.AT quant-ph
# cond-mat.soft physics.flu-dyn
# cs.LG cs.CL cs.NE stat.ML
# math.AP math.DG
# physics.app-ph
# cond-mat.quant-gas cond-mat.mtrl-sci cond-mat.other quant-ph
# physics.ins-det cond-mat.mtrl-sci
# math-ph cond-mat.stat-mech math.MP math.PR
# cond-mat.mes-hall cond-mat.mtrl-sci physics.app-ph physics.optics
# math.OC cs.CC cs.NA
# nucl-ex physics.atom-ph
# physics.chem-ph cond-mat.stat-mech cs.LG
# math-ph math.CA math.MP math.PR nlin.SI
# physics.atom-ph cond-mat.quant-gas physics.chem-ph quant-ph
# quant-ph cond-mat.stat-mech cond-mat.str-el hep-th
# quant-ph cond-mat.mes-hall cond-mat.quant-gas
# q-bio.GN
# stat.ML cond-mat.dis-nn cond-mat.stat-mech
# math.ST cs.SI stat.TH
# math.LO math.GR
# cond-mat.quant-gas nlin.PS
# math.NT math.RT
# q-bio.GN q-bio.QM
# cond-mat.quant-gas cond-mat.mes-hall physics.optics quant-ph
# physics.bio-ph cond-mat.soft q-bio.SC
# physics.bio-ph cond-mat.stat-mech math.DS
# cond-mat.mes-hall cond-mat.str-el cond-mat.supr-con
# math.NT math.AG math.GR math.RT
# hep-th cond-mat.other cond-mat.quant-gas gr-qc hep-ph
# cs.DM cs.CC math.CO quant-ph
# physics.optics cond-mat.mes-hall
# cond-mat.mtrl-sci quant-ph
# cond-mat.quant-gas math-ph math.MP
# quant-ph cs.ET cs.IT math.IT
# quant-ph math.CO
# cond-mat.quant-gas cond-mat.dis-nn physics.atom-ph quant-ph
# cond-mat.stat-mech cond-mat.quant-gas quant-ph
# cs.LG cs.CV stat.ML
# cs.IT eess.SP math.IT
# hep-ph astro-ph.HE hep-ex
# cond-mat.soft cond-mat.stat-mech physics.bio-ph q-bio.BM
# astro-ph.CO astro-ph.HE hep-ph
# physics.acc-ph physics.ins-det
# physics.geo-ph cs.SI physics.data-an stat.ML
# cond-mat.supr-con cond-mat.mtrl-sci cond-mat.str-el
# physics.optics cond-mat.mes-hall hep-ph hep-th
# math.RT math.CO math.QA
# cs.CR cs.LG
# math.NA physics.comp-ph physics.flu-dyn
# stat.ML cond-mat.stat-mech physics.data-an
# math.PR cond-mat.stat-mech cs.SI math.ST physics.soc-ph stat.TH
# cs.FL cs.DM cs.DS
# cond-mat.dis-nn cond-mat.quant-gas cond-mat.stat-mech cond-mat.str-el quant-ph
# physics.bio-ph q-bio.QM
# cond-mat.quant-gas cond-mat.str-el cond-mat.supr-con
# nlin.SI math-ph math.AP math.MP quant-ph
# math-ph cond-mat.stat-mech math.MP physics.chem-ph
# astro-ph.CO astro-ph.SR
# stat.ML cs.GR cs.LG
# math.HO
# hep-lat
# quant-ph cond-mat.quant-gas physics.app-ph
# physics.optics physics.class-ph
# q-bio.PE math.AP
# quant-ph cond-mat.str-el hep-lat hep-th
# gr-qc physics.space-ph
# cond-mat.supr-con quant-ph
# hep-th cond-mat.mes-hall math-ph math.MP quant-ph
# quant-ph cond-mat.other physics.chem-ph
# physics.optics cond-mat.mes-hall cond-mat.quant-gas
# cs.CC cs.LG math.NA math.OC
# cs.MM stat.AP
# physics.soc-ph q-fin.GN
# math-ph cs.IT math.IT math.MP math.PR quant-ph
# math.AP math.FA nlin.PS
# astro-ph.HE astro-ph.GA physics.plasm-ph
# math.AG math.AT math.NT
# math.CO math.RA
# cond-mat.dis-nn cond-mat.quant-gas cond-mat.stat-mech cond-mat.str-el
# quant-ph cs.AI stat.ML
# math.PR math.CO q-bio.PE
# math.CA hep-th math.NT
# physics.optics cond-mat.other physics.app-ph
# stat.ML math.ST stat.ME stat.TH
# hep-lat hep-ph nucl-th
# cs.CL cs.AI cs.LG cs.NE
# physics.gen-ph gr-qc hep-th
# cs.MS cs.NA math.NA
# math.ST physics.data-an stat.TH
# hep-ph astro-ph.CO hep-th
# cond-mat.quant-gas physics.optics quant-ph
# cond-mat.stat-mech math-ph math.MP
# astro-ph.CO astro-ph.GA hep-ph
# cond-mat.other cond-mat.mes-hall
# quant-ph cs.ET math.OC
# astro-ph.GA cond-mat.stat-mech
# cond-mat.str-el cond-mat.supr-con hep-th
# quant-ph astro-ph.IM
# math.RT math.AG math.CO
# math.CA nlin.SI
# physics.class-ph math.DS physics.ins-det
# nlin.CD nlin.AO
# cond-mat.soft q-bio.TO
# astro-ph.SR astro-ph.IM cs.CV
# physics.optics physics.atom-ph physics.chem-ph
# math.AG math.FA math.LO
# hep-lat hep-ex hep-ph
# physics.soc-ph math.DS
# q-fin.ST physics.soc-ph
# q-bio.TO
# stat.ME math.ST stat.TH
# astro-ph.CO astro-ph.GA cond-mat.stat-mech
# hep-lat cond-mat.dis-nn hep-ph
# q-bio.MN q-bio.QM
# cs.AI cs.RO
# cond-mat.soft math.MG
# cs.LG math.OC stat.ML
# physics.soc-ph cond-mat.dis-nn cs.SI nlin.AO
# math.OC cs.CC cs.DM cs.DS math.CO
# math.NA cs.CV math.DS math.FA math.OC
# cond-mat.dis-nn cond-mat.quant-gas cond-mat.stat-mech
# cond-mat.quant-gas cond-mat.supr-con
# q-fin.TR
# cond-mat.str-el cond-mat.quant-gas hep-ex physics.atom-ph
# cond-mat.supr-con cond-mat.quant-gas
# cs.NI cs.CR
# math.NT math.AP
# cs.IT cs.CL math.IT
# gr-qc astro-ph.HE hep-th
# nlin.AO cond-mat.stat-mech nlin.CD nlin.SI physics.soc-ph
# math.AC math.RA
# cond-mat.str-el cond-mat.mes-hall hep-th
# cond-mat.quant-gas nlin.CD
# math.OC cs.NA
# stat.ME cs.SI stat.AP stat.ML
# physics.optics physics.ins-det quant-ph
# math.MG math.AT math.GT
# cond-mat.stat-mech cond-mat.soft physics.data-an
# cond-mat.dis-nn cond-mat.mes-hall cond-mat.quant-gas
# physics.comp-ph cond-mat.stat-mech
# math.CA math.PR math.SP
# math.AC math.NT
# math.OC cs.SY nlin.AO
# cond-mat.mtrl-sci physics.class-ph physics.optics
# physics.flu-dyn math.AP
# physics.chem-ph physics.atm-clus
# cond-mat.str-el hep-lat hep-th
# cond-mat.str-el cond-mat.quant-gas quant-ph
# hep-th hep-lat hep-ph
# math-ph cond-mat.other math.MP physics.flu-dyn physics.optics
# cond-mat.mtrl-sci cond-mat.soft
# math.SG math.DG
# cs.CC math.CO
# q-bio.QM cond-mat.stat-mech nlin.CG
# physics.geo-ph
# cond-mat.str-el cond-mat.stat-mech hep-th math-ph math.MP
# cond-mat.dis-nn cond-mat.supr-con
# physics.soc-ph cond-mat.other nlin.AO
# math.MG math.OC
# cs.DC cs.MA
# cs.NE q-bio.NC
# physics.flu-dyn physics.chem-ph physics.comp-ph
# astro-ph.CO gr-qc hep-ph
# astro-ph.HE gr-qc
# cond-mat.quant-gas cond-mat.str-el cond-mat.supr-con quant-ph
# cond-mat.soft cond-mat.mes-hall cond-mat.mtrl-sci physics.chem-ph
# cs.SY cs.LG
# cond-mat.dis-nn cond-mat.stat-mech math-ph math.MP quant-ph
# quant-ph math.QA
# stat.AP physics.soc-ph
# cs.CG math.AG math.AT
# math.FA math.AP
# q-bio.SC
# nlin.PS physics.flu-dyn physics.optics
# quant-ph cond-mat.mtrl-sci cond-mat.other physics.bio-ph physics.chem-ph
# hep-th cond-mat.str-el gr-qc math-ph math.MP
# physics.ins-det quant-ph
# cond-mat.soft q-bio.CB
# quant-ph cond-mat.mtrl-sci physics.atom-ph physics.chem-ph physics.optics
# math.NT hep-th math.AG
# astro-ph.SR physics.space-ph
# math.AG math.CV math.DS
# cs.DL physics.soc-ph
# cond-mat.dis-nn cond-mat.stat-mech cs.DS
# math.CV math.CA
# physics.flu-dyn physics.class-ph physics.data-an physics.geo-ph
# quant-ph hep-th math-ph math.MP math.OA
# stat.ME physics.pop-ph
# physics.class-ph cond-mat.mes-hall cond-mat.other nlin.CD
# cs.RO cs.SY
# hep-ph hep-lat
# q-bio.PE physics.soc-ph
# math.PR math.FA math.SP
# cond-mat.stat-mech hep-lat
# cond-mat.stat-mech cond-mat.other math-ph math.MP nlin.PS
# cond-mat.supr-con physics.ins-det
# math.PR math.CO math.DS
# math-ph cond-mat.dis-nn math.MP quant-ph
# cond-mat.stat-mech physics.optics
# cond-mat.stat-mech cond-mat.str-el quant-ph
# gr-qc hep-lat hep-th
# stat.CO math.PR
# quant-ph cond-mat.stat-mech hep-th math-ph math.MP
# hep-ph astro-ph.CO astro-ph.HE hep-ex
# physics.soc-ph physics.app-ph
# physics.optics nlin.CD
# cond-mat.soft physics.comp-ph
# math.PR math.DG
# nucl-th astro-ph.HE
# cond-mat.dis-nn cond-mat.stat-mech physics.soc-ph
# math.CT math.PR
# math.OC cs.MA cs.SY
# physics.flu-dyn cs.NA math.CA math.DS
# cond-mat.mes-hall gr-qc hep-th
# cs.CY cs.SI
# cs.CR cs.NI
# hep-lat cond-mat.stat-mech hep-th
# astro-ph.GA astro-ph.SR
# math.RT math.AC
# cs.CL cond-mat.stat-mech cs.CY physics.soc-ph stat.AP
# cond-mat.mtrl-sci physics.comp-ph
# q-fin.MF math.NA math.PR
# physics.ins-det physics.data-an
# cs.CG math.MG
# gr-qc cond-mat.stat-mech hep-th
# stat.ME q-fin.RM
# cond-mat.str-el cond-mat.mes-hall cond-mat.stat-mech
# cond-mat.str-el cond-mat.quant-gas cond-mat.stat-mech
# q-bio.QM cs.LG cs.NE
# astro-ph.CO astro-ph.IM hep-ex physics.ins-det
# stat.AP physics.bio-ph
# cs.SI cs.HC
# physics.soc-ph cond-mat.stat-mech cs.IT math.IT
# math.PR cond-mat.stat-mech math-ph math.MP
# physics.soc-ph cond-mat.stat-mech cs.SI physics.data-an
# hep-th quant-ph
# cs.DL
# cond-mat.supr-con cond-mat.mes-hall cond-mat.str-el quant-ph
# cond-mat.quant-gas cond-mat.stat-mech hep-th quant-ph
# cs.CV cs.LG
# quant-ph nlin.CD
# math.OC cs.NI
# astro-ph.GA astro-ph.HE hep-ph
# hep-ph astro-ph.HE nucl-th
# math.NA cs.LG math.OC math.PR
# gr-qc math.CA
# cond-mat.quant-gas cond-mat.mes-hall cond-mat.supr-con physics.atom-ph
# quant-ph cond-mat.mes-hall cond-mat.mtrl-sci
# quant-ph cs.CR cs.DC
# quant-ph cond-mat.mes-hall physics.chem-ph
# astro-ph.EP astro-ph.SR
# nlin.AO physics.bio-ph q-bio.TO
# quant-ph cs.CC cs.IT math.IT
# cond-mat.str-el physics.comp-ph
# nlin.CD cond-mat.dis-nn
# cs.IT math.IT math.OC
# cond-mat.str-el cond-mat.stat-mech cond-mat.supr-con hep-th
# q-bio.QM
# cs.CE cs.NA cs.SY math.NA
# math-ph math.MP nlin.CD
# q-bio.NC nlin.AO
# stat.ML cs.LG cs.SI
# cond-mat.soft physics.bio-ph q-bio.BM
# cond-mat.stat-mech nlin.AO
# astro-ph.IM physics.chem-ph
# cs.AI cs.LO
# physics.atom-ph cond-mat.quant-gas nlin.PS
# cond-mat.mes-hall cond-mat.dis-nn cond-mat.str-el
# cond-mat.mes-hall cond-mat.soft
# physics.ins-det astro-ph.CO
# physics.comp-ph physics.acc-ph physics.plasm-ph
# cs.DS cs.GT
# math.QA hep-th math-ph math.MP math.OA
# physics.chem-ph cond-mat.mes-hall cond-mat.mtrl-sci cond-mat.other
# math.NT hep-th
# physics.optics cond-mat.mes-hall cond-mat.mtrl-sci
# ...
# q-fin.ST cs.CE cs.CV
# nlin.AO cond-mat.dis-nn physics.chem-ph q-bio.QM
# eess.SP cs.AR stat.CO stat.ME
# cs.CV cs.GR cs.HC
# cs.LG cs.DB stat.ML
# cond-mat.supr-con cond-mat.dis-nn cond-mat.mes-hall cond-mat.mtrl-sci
# physics.optics nlin.PS physics.bio-ph q-bio.BM
# nlin.PS nlin.CD
# hep-lat hep-ex hep-ph hep-th
# cs.SI cond-mat.stat-mech
# astro-ph.GA hep-ex hep-ph
# cs.DS cs.DC cs.PF
# cs.IR cs.DC cs.LG cs.SI
# cs.CV cs.DC cs.PL
# cond-mat.dis-nn cond-mat.str-el hep-lat
# astro-ph.IM astro-ph.EP astro-ph.SR cs.LG
# eess.SP cs.SY eess.SY math.DS
# cs.RO cs.SY eess.SY quant-ph
# physics.geo-ph nlin.PS physics.flu-dyn
# cs.CL cs.LG cs.SI
# hep-ph cond-mat.supr-con gr-qc
# cs.NI cs.CY cs.DS
# physics.flu-dyn cond-mat.mtrl-sci
# eess.SP stat.AP
# astro-ph.SR physics.geo-ph physics.space-ph
# cs.IR cs.AI cs.HC cs.NE
# cs.SI cs.CR cs.CY
# cs.DS math.ST stat.ML stat.TH
# astro-ph.HE astro-ph.IM astro-ph.SR hep-ph
# q-bio.TO cond-mat.soft
# cs.CL cond-mat.stat-mech
# cond-mat.mtrl-sci physics.atom-ph physics.chem-ph physics.comp-ph
# q-bio.MN math.OC
# cs.IR cs.CL cs.DL cs.LG
# cs.AR cs.LG cs.PF
# q-bio.TO cond-mat.stat-mech math.DS nlin.AO physics.bio-ph
# eess.SY cs.AI cs.RO cs.SY
# physics.med-ph eess.SP physics.ins-det
# cond-mat.soft cond-mat.dis-nn cond-mat.stat-mech physics.class-ph
# physics.flu-dyn math.DS nlin.CD physics.comp-ph stat.ML
# physics.bio-ph cs.AI
# physics.app-ph astro-ph.IM physics.optics
# physics.flu-dyn physics.app-ph physics.geo-ph
# physics.acc-ph cond-mat.other physics.class-ph
# physics.optics physics.flu-dyn
# q-bio.NC cond-mat.dis-nn cond-mat.stat-mech
# math-ph cond-mat.stat-mech math.DS math.MP
# cs.CV cs.AI cs.RO
# astro-ph.SR astro-ph.EP cs.LG
# physics.ins-det physics.ao-ph
# hep-th astro-ph.CO cond-mat.other gr-qc hep-ph
# cs.LG cs.CV cs.RO stat.ML
# q-bio.QM cs.LG physics.bio-ph
# physics.optics cond-mat.dis-nn cs.ET math.OC nlin.AO
# cs.CV cs.HC cs.RO
# physics.flu-dyn cs.CE cs.NA math.NA
# stat.ME stat.OT
# physics.class-ph physics.atom-ph
# cs.CV cs.LG cs.SY eess.SY
# nlin.AO cond-mat.dis-nn math.DS
# physics.space-ph astro-ph.EP astro-ph.HE physics.plasm-ph
# cs.CY cs.DL
# cs.CV cs.AI cs.MM
# eess.SY cs.SY math.AG math.DS
# q-bio.BM q-bio.TO
# cond-mat.str-el hep-th math.CT math.QA
# math.NA cs.NA math.PR physics.comp-ph
# quant-ph cs.DM cs.ET
# physics.data-an astro-ph.IM
# cond-mat.soft cond-mat.dis-nn physics.comp-ph physics.data-an
# cs.CV cs.LG cs.SD eess.AS
# cond-mat.dis-nn physics.chem-ph
# math.GT math.AT math.RA
# cond-mat.soft cond-mat.mtrl-sci cond-mat.stat-mech nlin.PS physics.flu-dyn
# physics.med-ph cs.CV cs.CY
# nlin.AO cond-mat.dis-nn math.DS physics.bio-ph
# cond-mat.mes-hall cond-mat.stat-mech physics.comp-ph
# cond-mat.soft cond-mat.other physics.flu-dyn
# astro-ph.GA astro-ph.CO physics.data-an
# cs.LO cs.FL cs.GT
# hep-ph hep-ex hep-th nucl-ex
# nlin.CD nlin.AO quant-ph
# cs.LG cs.CV cs.CY eess.IV
# cs.LG cs.GT cs.NI
# physics.app-ph physics.ed-ph physics.ins-det physics.plasm-ph
# cond-mat.mes-hall cond-mat.mtrl-sci cond-mat.str-el cond-mat.supr-con quant-ph
# astro-ph.SR astro-ph.HE astro-ph.IM physics.space-ph
# cond-mat.mes-hall cond-mat.soft physics.app-ph
# cs.IR cs.CY
# astro-ph.IM astro-ph.EP physics.space-ph
# eess.SP cs.CY stat.AP
# physics.ed-ph astro-ph.IM cs.CY
# cs.CL cs.LG cs.LO
# cs.CL cs.HC cs.LG
# q-bio.PE stat.AP stat.ML
# cs.CY cs.AR cs.CV
# cs.MA cs.GR
# cs.LG cs.AI cs.SY eess.SY stat.ML
# physics.chem-ph cond-mat.mtrl-sci cond-mat.other physics.plasm-ph
# cs.MS physics.data-an physics.ins-det
# physics.bio-ph q-bio.CB q-bio.GN
# cond-mat.stat-mech astro-ph.HE physics.comp-ph
# cond-mat.soft nlin.AO nlin.PS
# cs.CL cs.AI cs.CY cs.LG
# cs.AI cs.HC cs.LG
# cs.SI cs.LG physics.soc-ph q-bio.QM
# cs.CL cs.AI cs.MA
# nlin.CD cond-mat.stat-mech quant-ph
# cond-mat.quant-gas cond-mat.dis-nn cond-mat.mtrl-sci cond-mat.stat-mech cond-mat.str-el
# cs.HC cs.CR
# physics.app-ph cs.LG
# physics.flu-dyn cond-mat.dis-nn cond-mat.soft physics.geo-ph
# hep-ex hep-ph nucl-ex nucl-th physics.ins-det
# cs.LG cs.CL cs.IR
# eess.AS cs.CL cs.LG cs.SD stat.ML
# cs.NI quant-ph
# cs.CV cs.CR eess.IV
# physics.geo-ph cs.LG stat.AP stat.ML
# quant-ph cs.LG physics.optics stat.ML
# physics.plasm-ph nlin.PS
# cs.SD cs.HC eess.AS
# cond-mat.mes-hall cond-mat.mtrl-sci cond-mat.soft physics.app-ph physics.chem-ph
# cs.LG cs.AR cs.PL
# astro-ph.EP physics.comp-ph physics.geo-ph physics.optics
# cs.AI cs.CY cs.HC
# cs.CL cs.FL cs.LG
# eess.IV cs.LG eess.SP
# cs.IR cs.CG cs.CV physics.optics
# cs.MM cs.GR
# physics.chem-ph cond-mat.str-el physics.atm-clus physics.comp-ph
# cs.SD cs.LG eess.AS quant-ph
# cs.LG cs.NE
# cs.NI cs.GT cs.LG cs.MA
# cs.SD cs.HC cs.LG eess.AS
# q-fin.RM q-fin.CP q-fin.ST
# cs.LG q-bio.MN stat.AP stat.ML
# q-bio.PE q-bio.MN q-bio.QM
# cs.AI cs.LG physics.flu-dyn physics.soc-ph
# physics.chem-ph nucl-th
# cs.CY cs.MA cs.SE
# physics.data-an cs.NE
# cs.SD eess.AS q-bio.NC
# nlin.PS cond-mat.mes-hall cond-mat.soft physics.chem-ph
# hep-th hep-lat hep-ph quant-ph
# physics.app-ph cond-mat.mtrl-sci cs.NA math.NA
# cs.AI cs.CL cs.IR cs.LG
# cs.DB cs.AI cs.CL
# gr-qc astro-ph.CO astro-ph.HE astro-ph.SR
# cs.LG cs.AI cs.SY eess.SY
# q-bio.QM cs.LG q-bio.GN q-bio.PE
# physics.chem-ph physics.acc-ph physics.app-ph
# cs.CR cs.AI cs.CV cs.LG
# eess.SY astro-ph.IM cs.SY
# cond-mat.dis-nn cond-mat.stat-mech physics.comp-ph physics.data-an
# cs.AR cs.DC cs.NI
# cs.MA cs.DC
# q-bio.NC cs.AI cs.LG cs.RO
# cond-mat.dis-nn physics.geo-ph
# cs.LG cs.DC
# cond-mat.mtrl-sci physics.flu-dyn
# physics.optics cs.NE physics.comp-ph
# q-fin.TR cs.MA
# eess.SY cs.CR cs.SY math.OC
# quant-ph cs.LO math.PR
# cs.SD eess.AS physics.app-ph
# physics.optics cond-mat.mtrl-sci physics.app-ph physics.comp-ph
# physics.plasm-ph astro-ph.HE physics.comp-ph
# math-ph math.DG math.MP quant-ph
# cs.LG cs.DS
# cs.DC cs.AR cs.DS
# q-bio.NC cs.SY eess.SY
# math.CO math.FA math.NT
# cs.GR astro-ph.IM math.MG physics.data-an
# cs.LG cs.CV cs.IT cs.MM math.IT
# cs.DC cs.PF cs.SE
# cs.DS cs.DB cs.DC cs.IR
# physics.atom-ph hep-ph physics.ins-det physics.plasm-ph quant-ph
# cs.CR cs.CV
# cs.LG cs.AI cs.CL
# cs.DM math.MG q-bio.MN
# cond-mat.mtrl-sci eess.IV
# physics.space-ph physics.ao-ph
# cs.AR cs.LG eess.IV
# cs.SI cs.GT
# cs.LG cs.CV q-bio.QM
# physics.atom-ph astro-ph.IM physics.acc-ph physics.ins-det physics.plasm-ph
# eess.SP cs.LG cs.SD eess.AS
# cs.LG nlin.CD
# cs.LG physics.flu-dyn stat.AP
# physics.class-ph hep-th physics.plasm-ph
# astro-ph.IM astro-ph.EP astro-ph.GA astro-ph.HE astro-ph.SR
# physics.bio-ph cond-mat.soft physics.flu-dyn physics.med-ph
# physics.med-ph cs.CV cs.LG
# physics.gen-ph physics.optics
# physics.pop-ph astro-ph.IM cs.CY
# cs.RO cs.HC cs.SY eess.SY
# cond-mat.soft physics.flu-dyn physics.optics
# cs.RO cs.AI cs.LG cs.MA cs.NE
# econ.GN physics.soc-ph q-fin.EC stat.AP
# physics.data-an cs.LG stat.ME
# math.CO math.CA math.FA math.NT
# cs.HC cs.MM
# astro-ph.IM astro-ph.EP astro-ph.GA astro-ph.SR physics.chem-ph
# cond-mat.mes-hall physics.app-ph physics.comp-ph
# cs.LG cs.AI cs.CV cs.RO
# cs.ET cond-mat.stat-mech cs.CC cs.NE
# cs.LG q-bio.BM
# astro-ph.EP physics.ao-ph physics.flu-dyn physics.geo-ph
# cs.CY cs.DB
# math.LO cs.CC math.RA
# physics.chem-ph cond-mat.mtrl-sci cs.LG
# cs.LG cond-mat.mtrl-sci physics.chem-ph
# physics.atm-clus cond-mat.quant-gas physics.chem-ph
# cs.LG cs.CL cs.CV
# astro-ph.EP astro-ph.IM physics.chem-ph physics.space-ph
# physics.flu-dyn math.DS nlin.CD
# eess.SP cs.AI cs.CV cs.LG cs.RO
# q-bio.MN cs.IT math.IT q-bio.SC stat.CO
# astro-ph.EP physics.class-ph
# q-bio.QM cs.LG cs.SY eess.SY
# eess.SP physics.med-ph
# eess.IV cs.CV cs.PF
# cs.NI cs.OS
# physics.atm-clus cond-mat.quant-gas physics.atom-ph
# cs.RO cs.CC cs.MA
# cs.AI cs.LG cs.NI cs.SE
# astro-ph.EP astro-ph.HE astro-ph.IM astro-ph.SR
# cs.RO cs.SE
# cs.LG cs.AR
# astro-ph.EP math.OC
# cs.IR cs.MS
# cond-mat.soft cond-mat.mtrl-sci physics.bio-ph physics.flu-dyn
# cs.NE cs.NI
# cond-mat.supr-con cond-mat.mtrl-sci physics.ins-det
# cs.SD cs.DB cs.IR cs.MM eess.AS
# physics.plasm-ph cond-mat.stat-mech physics.ao-ph
# cond-mat.dis-nn cond-mat.stat-mech physics.bio-ph physics.comp-ph quant-ph
# cs.LG cs.DS math.CO
# astro-ph.EP astro-ph.HE astro-ph.SR physics.space-ph
# eess.SY cs.AR cs.SY eess.SP
# cs.LO cs.AI cs.RO
# cs.FL cs.SC
# cs.LG cs.AI math.ST stat.ML stat.TH
# cond-mat.mes-hall cond-mat.mtrl-sci physics.app-ph quant-ph
# astro-ph.IM quant-ph
# cond-mat.mtrl-sci cond-mat.stat-mech physics.chem-ph physics.class-ph physics.comp-ph
# physics.ao-ph cs.LG
# math.DS nlin.AO physics.chem-ph
# physics.atom-ph cond-mat.quant-gas nucl-th
# physics.plasm-ph astro-ph.IM cond-mat.stat-mech physics.space-ph
# cond-mat.mes-hall cond-mat.str-el nlin.PS nlin.SI physics.optics
# cs.MM cs.LG
# cond-mat.soft cs.NA cs.SY eess.SY math.DG math.NA
# cs.LG stat.AP
# cs.LG cs.AI math.OC q-fin.ST
# cs.AI cs.DS
# astro-ph.IM astro-ph.HE physics.ins-det
# astro-ph.IM cond-mat.supr-con
# cs.CY cs.AI cs.DC
# cond-mat.stat-mech physics.chem-ph quant-ph
# stat.ML cs.AI cs.LG q-bio.GN
# stat.ME q-bio.GN q-bio.QM stat.AP stat.ML
# physics.ao-ph cs.LG physics.comp-ph stat.AP
# cs.CR physics.optics quant-ph
# math-ph math.AG math.MP
# physics.space-ph astro-ph.EP physics.ao-ph physics.comp-ph physics.flu-dyn
# physics.class-ph eess.SP
# physics.optics cond-mat.stat-mech nlin.PS
# astro-ph.GA astro-ph.SR gr-qc
# cs.MM cs.AI cs.CV
# q-bio.TO cs.SD eess.AS eess.SP q-bio.NC
# cs.RO cs.CV cs.HC cs.LG
# cs.HC cs.CY cs.MM cs.SI
# astro-ph.IM astro-ph.EP physics.geo-ph physics.space-ph
# cs.MA cs.LG cs.PL
# nucl-ex cond-mat.mtrl-sci physics.ins-det
# cs.CR cs.CY cs.SY eess.SY
# math.AP cs.NA math.NA
# cs.HC cs.CY cs.MM
# stat.AP physics.app-ph physics.data-an
# cs.CY cs.CL cs.LG q-bio.QM
# cs.IR cs.HC cs.LG
# physics.pop-ph astro-ph.CO hep-ph
# q-bio.QM cs.AI cs.LG
# cs.PL cs.DS
# physics.acc-ph cond-mat.mes-hall cond-mat.mtrl-sci physics.comp-ph physics.plasm-ph
# astro-ph.IM astro-ph.CO gr-qc hep-ex hep-ph
# cs.CL cs.CY q-bio.QM
# astro-ph.IM astro-ph.GA astro-ph.SR physics.atom-ph
# cs.DL cs.IR cs.LG
# cs.DL cs.DB cs.IR
# eess.IV cs.CC cs.CV cs.LG cs.MM
# cs.CV cs.CL cs.MM
# physics.comp-ph cs.ET cs.NA math.NA
# math.NA cs.NA math.CV
# math.HO math.DS
# physics.ao-ph astro-ph.EP physics.space-ph stat.AP
# cs.SI cs.MA cs.SY eess.SY math.DS physics.soc-ph
# nlin.AO physics.bio-ph q-bio.PE
# nlin.CD math.OC
# eess.SP cs.LG eess.IV
# eess.IV cs.AI cs.LG
# cs.CV cs.AI cs.LG cs.MM cs.NE
# physics.bio-ph physics.app-ph q-bio.CB
# physics.bio-ph cond-mat.stat-mech physics.data-an
# cs.AR cs.LG cs.NA math.NA
# cs.AR cs.DC
# hep-ph physics.atom-ph physics.class-ph
# physics.app-ph cs.SY eess.SY physics.optics
# q-bio.MN cs.LG q-bio.BM q-bio.GN
# cs.AI cs.RO cs.SE
# cs.OH cs.AI
# cs.NI q-bio.MN
# q-fin.PR
# physics.soc-ph cs.CY econ.GN q-fin.EC
# q-bio.MN cs.NI
# astro-ph.CO astro-ph.GA gr-qc physics.comp-ph
# cs.RO cs.AI cs.CV cs.SY eess.SY
# cond-mat.soft cond-mat.dis-nn cond-mat.mes-hall cond-mat.mtrl-sci physics.flu-dyn
# physics.plasm-ph physics.class-ph
# cs.LG cs.SY eess.SY math.OC
# nlin.AO cond-mat.dis-nn cs.SY eess.SY q-bio.QM
# cs.IR cs.AI cs.DL
# cs.DB cs.LG cs.PF
# cs.MA cs.GT cs.SY eess.SY
# physics.med-ph cs.CV cs.GR cs.RO
# q-bio.PE cs.GT physics.soc-ph
# physics.hist-ph physics.soc-ph
# math.OC cs.GT
# cs.SD cs.DL eess.AS
# cs.AI cs.MM
# astro-ph.HE hep-ex physics.space-ph
# math.CO math.LO
# cs.SD eess.AS math.CO
# cs.CV cs.AR eess.IV
# math.NT math.CO math.CV
# cs.SI cs.DL physics.data-an
# cs.DC cs.RO
# math.CT math.GR
# cs.LG cs.AI cs.SI
# eess.SY cs.CR cs.SY
# cs.SI cs.CL physics.soc-ph
# q-bio.PE cs.NA math.DS math.NA math.OC stat.CO
# physics.ao-ph astro-ph.EP physics.geo-ph
# econ.EM cs.CL cs.SI
# cs.CL cs.SI econ.GN physics.soc-ph q-fin.EC
# econ.GN cs.CL q-fin.EC q-fin.GN
# math.CA math-ph math.FA math.MG math.MP math.OC
# physics.pop-ph astro-ph.SR
# cs.SI econ.GN q-fin.EC
# cs.LG cs.AI stat.AP
# math.GT hep-th math-ph math.MP
# physics.data-an physics.bio-ph q-bio.QM stat.ME
# q-fin.ST cs.LG eess.SP
# cs.CR cs.DS
# physics.app-ph cond-mat.mtrl-sci cond-mat.str-el physics.ins-det
# cs.NI cs.CY cs.PF
# physics.pop-ph astro-ph.SR physics.hist-ph
# physics.optics nlin.CD physics.app-ph
# cs.AI q-bio.QM
# cs.AI cs.DC cs.LO cs.NI
# math.AG cs.IT math.IT
# cs.LG cs.CY
# cs.LG cs.CV physics.ins-det
# math.NA cs.NA eess.SP
# quant-ph physics.atom-ph physics.comp-ph
# nlin.AO math.DS nlin.CD
# q-bio.NC eess.SP
# cs.GT cs.LG
# cs.LG cs.DB
# cs.DB cs.CR cs.DC
# stat.CO cs.AI cs.NA eess.SP math.NA
# math.LO math.PR
# cond-mat.stat-mech cs.CE physics.class-ph stat.AP
# q-fin.ST cs.LG stat.ML
# eess.SY cs.MA cs.SY math.OC
# cs.CE cs.NA math.NA math.OC stat.CO stat.ME
# math.NA cs.CE cs.NA physics.flu-dyn
# cs.CE math-ph math.MP
# cond-mat.mtrl-sci physics.app-ph physics.optics physics.plasm-ph
# cond-mat.mes-hall cond-mat.mtrl-sci cond-mat.str-el physics.app-ph
# q-bio.SC q-bio.CB
# q-bio.QM q-bio.SC
# q-bio.QM q-bio.CB
# cs.HC cs.CY cs.GT
# cond-mat.str-el cond-mat.mtrl-sci math-ph math.MP quant-ph
# physics.geo-ph cond-mat.mtrl-sci physics.app-ph
# cond-mat.mes-hall cond-mat.dis-nn cond-mat.mtrl-sci physics.app-ph quant-ph
# cs.CL cs.AI cs.IR cs.LG cs.SI
# cs.MA cs.AI cs.CY
# cond-mat.soft nlin.PS physics.app-ph
# cs.IR cs.SI econ.GN q-fin.EC
# stat.AP math.ST stat.ME stat.TH
# nlin.PS cs.NA math.NA
# eess.SP cs.LG cs.NI
# eess.SY cs.AI cs.SY
# cs.CV cs.CG cs.GR
# physics.ed-ph cs.GR cs.HC math.HO
# nlin.AO nlin.PS physics.app-ph physics.chem-ph
# physics.soc-ph cond-mat.mtrl-sci
# cs.PF cs.DC cs.NI
# eess.IV cs.AI cs.CV
# physics.soc-ph cond-mat.stat-mech q-bio.QM
# cs.LG cs.DC cs.NE
# cs.RO cs.DS cs.MA
# cs.SE cs.AI cs.RO cs.SY eess.SY
# cs.SE cs.NI cs.RO
# math.CA math.GT
# cs.LG cs.AI cs.CV cs.NE
# cs.PF cs.IR
# q-bio.QM cs.LG eess.SP
# astro-ph.EP math.DS
# cs.DL cs.HC
# cs.SE cs.DB
# math.CT math.AT math.KT
# cond-mat.quant-gas cond-mat.supr-con physics.flu-dyn quant-ph
# cs.LG cs.AI cs.CV
# cond-mat.str-el cond-mat.mtrl-sci cond-mat.stat-mech cond-mat.supr-con
# astro-ph.IM astro-ph.GA physics.atom-ph
# cs.LG cs.CE cs.SY eess.SY
# cs.LG cs.DS cs.NA math.NA
# cs.DB cs.FL
# astro-ph.IM physics.atom-ph physics.plasm-ph
# eess.IV cs.CV cs.IR
# cs.CE cs.SY eess.SY
# physics.chem-ph astro-ph.IM physics.atom-ph physics.plasm-ph
# cs.RO cs.AR
# physics.optics physics.class-ph physics.pop-ph
# cs.CV cs.LG cs.NE cs.RO
# cs.LG cs.CY physics.geo-ph
# physics.optics cond-mat.other physics.app-ph physics.class-ph physics.comp-ph
# cs.SE cs.AI cs.LG
# math.NA cs.DC cs.NA
# cs.CR cs.CV cs.HC
# eess.SP cs.LG cs.SY eess.SY stat.AP
# eess.IV cs.CV cs.HC
# physics.geo-ph physics.class-ph physics.ins-det
# eess.SP cs.NA math.NA physics.app-ph
# stat.ME cs.CV eess.IV math.ST physics.data-an stat.TH
# eess.IV cs.CV stat.AP stat.ME
# physics.pop-ph nlin.PS physics.ed-ph
# cond-mat.mes-hall cond-mat.mtrl-sci math-ph math.MP physics.comp-ph
# eess.SP cs.NA cs.SY eess.SY math.NA physics.ins-det stat.ME
# eess.SP cs.NA cs.SY eess.SY math.NA stat.ME
# stat.ME eess.IV eess.SP physics.data-an physics.ins-det
# cs.LG cs.CC cs.CV eess.SP stat.ME
# stat.ME cs.CV eess.IV physics.data-an stat.AP
# astro-ph.IM physics.ao-ph physics.ins-det
# cs.LG cs.DS math.PR
# eess.SY cs.AR cs.SY
# cs.AR cs.DC cs.SY eess.SY
# eess.SP cs.CV cs.LG q-bio.NC
# cs.LG cs.AI cs.CY
# physics.soc-ph physics.ed-ph
# physics.ed-ph physics.soc-ph
# cond-mat.soft cond-mat.stat-mech physics.bio-ph physics.comp-ph
# cs.CR cs.AI cs.DC cs.LG
# cs.CY cs.AI cs.CL
# physics.flu-dyn cs.LG
# stat.ME q-bio.GN stat.AP
# physics.ed-ph cs.RO
# cs.LG cs.AI cs.IR cs.NE
# cs.HC cs.LG cs.SD eess.AS eess.IV
# cs.RO cs.MA cs.SY eess.SY
# eess.SY cs.NI cs.SY eess.SP
# q-fin.RM q-fin.MF
# astro-ph.GA astro-ph.SR physics.flu-dyn
# cs.AR cs.AI cs.NE
# physics.chem-ph cond-mat.stat-mech physics.comp-ph
# cs.RO cs.LG eess.SP
# stat.AP math.PR stat.ME stat.OT
# cs.AI cs.IT cs.RO cs.SY eess.SY math.IT
# cs.AI cs.IT cs.SY eess.SY math.IT
# nlin.CD math.PR physics.chem-ph
# eess.SP physics.med-ph physics.optics
# astro-ph.EP cond-mat.mtrl-sci
# cs.IT cs.AI math.IT
# cs.AI cs.SC
# math.AG math.SG
# cs.DL cs.AI cs.CL cs.LG
# math.AT math.GN
# eess.AS cs.CL cs.SD eess.SP
# eess.AS cs.CL cs.LG cs.SD eess.SP
# q-fin.ST cs.LG cs.SI
# cs.SE cs.AI cs.NE
# cond-mat.soft cs.NA math.AP math.NA physics.bio-ph q-bio.CB
# physics.data-an nlin.CD physics.ao-ph
# cs.DM cs.NA math.NA
# cs.CR cs.SY eess.SP eess.SY
# stat.ME math.PR
# math.DS physics.soc-ph
# eess.SP cs.AR cs.SD eess.AS
# nlin.SI math.AP
# stat.ME cs.ET math.ST stat.TH
# cs.CR cs.LG cs.MM eess.IV
# cs.RO cs.CL cs.CV cs.LG
# physics.soc-ph cs.CY physics.app-ph
# cond-mat.mtrl-sci cond-mat.soft cond-mat.stat-mech physics.chem-ph
# cs.DC cs.HC
# math.CO stat.AP
# cs.LG cs.SY eess.SY
# cs.CV q-bio.PE
# astro-ph
# chao-dyn nlin.CD
# gr-qc astro-ph hep-th
# math-ph hep-ph hep-th math.CA math.MP physics.class-ph
# math.AG math.GT math.KT math.OA
# math.CA math.QA
# q-alg math.QA
# solv-int nlin.SI

# %%
ml_df = df[df['categories'].str.contains("cs.")]

sentenceList = ml_df["abstract"].tolist()

# %%
print(len(ml_df))
# Out:
# 27671

# %%
print(sentenceList[0])
# Out:
#   In this paper we leave the neighborhood of the singularity at the origin and
# turn to the singularity at the horizon. Using nonlinear superdistributional
# geometry and supergeneralized functions it seems possible to show that the
# horizon singularity is not only a coordinate singularity without leaving
# Schwarzschild coordinates. However the Tolman formula for the total energy $E$
# of a static and asymptotically flat spacetime,gives $E=mc^2$, as it should be.
# New class Colombeau solutions to Einstein field equations is obtained.New class
# Colombeau solutions to Einstein field equations is obtained. The vacuum energy
# density of free scalar quantum field ${\Phi}$ with a distributional background
# spacetime also is considered.It has been widely believed that, except in very
# extreme situations, the influence of acceleration on quantum fields should
# amount to just small, sub-dominant contributions. Here we argue that this
# belief is wrong by showing that in a Rindler distributional background
# spacetime with distributional Levi-Civit\`a connection the vacuum energy of
# free quantum fields is forced, by the very same background distributional
# space-time such a Rindler distributional background space-time, to become
# dominant over any classical energy density component.This semiclassical gravity
# effect finds its roots in the singular behavior of quantum fields on a Rindler
# distributional space-times with distributional Levi-Civit\`a connection. In
# particular we obtain that the vacuum fluctuations $<{\Phi}^2({\delta})>$ have a
# singular behavior at a Rindler horizon $\delta = 0$.Therefore sufficiently
# strongly accelerated observer burns up near the Rindler horizon. Thus
# Polchinski account does not violate of the Einstein equivalence principle.

# %%
samplesentenceList = sentenceList[1:2500]

# %%
topic_model = BERTopic(calculate_probabilities=True)
topics,prob = topic_model.fit_transform(samplesentenceList)

# %%
topic_model.get_topic_info(1)
# Out:
#    Topic  Count                 Name  \
# 0      1     69  1_cell_cells_of_the
#
#                                       Representation  \
# 0  [cell, cells, of, the, and, in, model, we, to,...
#
#                                  Representative_Docs
# 0  [  Bacterial colonies are abundant on living a...

# %%
topic_model.get_topic(1)
# Out:
# [('cell', 0.020806289095481927),
#  ('cells', 0.018060471187736054),
#  ('of', 0.01753105853595493),
#  ('the', 0.015408679077212531),
#  ('and', 0.013698921609343164),
#  ('in', 0.013440170748293184),
#  ('model', 0.012723845729518572),
#  ('we', 0.01271308602938116),
#  ('to', 0.01259673793780043),
#  ('that', 0.011972756568916153)]

# %%
topic_model.visualize_topics()

# %%
topic_model.visualize_heatmap()

# %%
topic_model.visualize_hierarchy()

# %%
from sklearn.decomposition import PCA 
from sklearn.cluster import KMeans

# %%
dim_model = PCA(n_components=5)
cluster_model = KMeans(n_clusters=50)

topic_model = BERTopic(umap_model=dim_model,embedding_model="allenai-specter",
                       hdbscan_model=cluster_model,calculate_probabilities=True)

# %%
topics,probabilities = topic_model.fit_transform(samplesentenceList)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/2.77k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/622 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/331 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/222k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/462k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
topic_model.get_topic_info(1)
# Out:
#    Topic  Count                Name  \
# 0      1     90  1_graphs_we_of_for
#
#                                       Representation  \
# 0  [graphs, we, of, for, problem, that, graph, th...
#
#                                  Representative_Docs
# 0  [  Here we study the NP-complete $K$-SAT probl...

# %%
topic_model.visualize_barchart()
